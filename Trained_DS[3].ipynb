# %%
import torch
import pandas as pd
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load the pre-trained model and tokenizer
model_names = ['gpt2', './gpt2-finetuned-recipes-main', './gpt2-finetuned-recipes-bakery', './gpt2-finetuned-recipes-drinks', './gpt2-finetuned-recipes-meal']
#model_names = ['gpt2','./gpt2-finetuned-recipes-meal']
models = {}

for model_name in model_names:
    tokenizer = GPT2Tokenizer.from_pretrained(model_name)
    letemcook = GPT2LMHeadModel.from_pretrained(model_name)
    # Set the model to evaluation mode
    letemcook.eval()
    models[model_name] = (tokenizer, letemcook)
# Out:
# 2024-11-22 09:38:14.397271: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-22 09:38:14.398734: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-22 09:38:14.423514: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-22 09:38:14.855639: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
test_datasets = []

test_dataset_names = ['Datasets/main_test_dataset.csv', 'Datasets/bakery_test_dataset.csv', 'Datasets/drinks_test_dataset.csv', 'Datasets/meal_test_dataset.csv']

for test_dataset_name in test_dataset_names:
    test_datasets.append(pd.read_csv(test_dataset_name))

# %%
# Function to generate text completion
def generate_completion(model, prompt, max_length=20):
    # Encode the input prompt
    inputs = tokenizer.encode(prompt, return_tensors='pt')
    # Generate output
    with torch.no_grad():
        outputs = model.generate(inputs, max_new_tokens=max_length, min_length = 3, temperature=0.5, do_sample=True)

    # Decode the generated output
    completion = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return completion

def make_prompt(title, ingredients, complete_instruction_steps, incomplete_instruction_steps):
    pre_prompt = "You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] "
    title_prompt = f"[RECIPE_TITLE] {title} " 
    ingredients_prompt = f"[INGREDIENTS_LIST] {ingredients} " 
    
    instructions_prompt = f"[STEPS] "
    for i, step in enumerate(complete_instruction_steps):
        instructions_prompt += f"{i + 1} - {step} "
    instructions_prompt += " " + f"{len(complete_instruction_steps) + 1} - {incomplete_instruction_steps}"
    
    prompt = pre_prompt + title_prompt + ingredients_prompt + instructions_prompt
    # prompt = pre_prompt + instructions_prompt
    return prompt

def autocomplete_recipe_step(model, title, ingredients, complete_instruction_steps, incomplete_instruction_steps, print_prompt = False, completiion_only = True):
    prompt = make_prompt(title, ingredients, complete_instruction_steps, incomplete_instruction_steps)
    if print_prompt: print(prompt)
    generated_string = generate_completion(model, prompt)
    if completiion_only:
        return generated_string[len(prompt):]
    return generated_string


def convert_string_to_list(input_string):
    clean_string = input_string.strip('[]')
    return [s.strip().strip('"') for s in clean_string.split('", "')] # assuming this is always a good split

def index_of_instruction_word(text, n):
    words = text.split()
    
    if n > len(words):
        return len(text) -1  
    
    position = 0
    for word in words[:n-1]:
        position += len(word) + 1 
    
    return position

def remove_next_step(step_number_to_remove, generated_autocompletion):
    next_step_token = f" {3} - "
    return generated_autocompletion.split(next_step_token, 1)[0]

from IPython.display import display, HTML
def display_prompt(text):
    display(HTML(f"<h1>Prompt</h1><p>{text}</p>"))

# %%
# Change nrows if desired
df = test_datasets[3]

# %%
def separate_recipe_components(recipe_index, n_complete_steps=2, n_words_before_autocomplete=3):

    test_rec = df.iloc[recipe_index, :]

    title = test_rec["title"]
    ingredients = test_rec["ingredients"]
    steps = convert_string_to_list(test_rec["directions"])
    #if n_complete_steps == None or len(steps) < n_complete_steps : return title, ingredients, steps, "", ""
    
    

    if len(steps) <= n_complete_steps: return title, ingredients, steps[0:len(steps)-1], steps[len(steps)-1], steps[len(steps)-1]
    
    complete_steps = steps[:n_complete_steps - 1]

    true_step = steps[n_complete_steps]
    n_characters_before_autocomplete = index_of_instruction_word(true_step, n_words_before_autocomplete) # Not used for now
    incomplete_instruction_step = true_step[0:n_characters_before_autocomplete]
    rest_of_instruction_step = true_step[n_characters_before_autocomplete:]
    
    return title, ingredients, complete_steps, incomplete_instruction_step, rest_of_instruction_step

# %%
n_steps = 2
n_words_before_autocomplete = 3


for model_name in models:
    title, ingredients, complete_steps, incomplete_instruction_step, rest_of_instruction_step = separate_recipe_components(1, n_complete_steps=n_steps, n_words_before_autocomplete=n_words_before_autocomplete)
    original_prompt = make_prompt(title, ingredients, complete_steps, incomplete_instruction_step)
    autocompleted_step = autocomplete_recipe_step(models[model_name][1], title, ingredients, complete_steps, incomplete_instruction_step)
    # not yet implemented
    autocompleted_step = remove_next_step(n_steps + 1, autocompleted_step)
    print(original_prompt)
    print("-" * 80)
    print(autocompleted_step)
    print("-" * 80)
    print(rest_of_instruction_step)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] [RECIPE_TITLE] Old Fashioned Nostalgic Maruboro [INGREDIENTS_LIST] ["200 grams Cake flour", "2 Eggs", "130 grams Dark brown sugar", "3 tbsp Honey", "1 tsp Baking soda"] [STEPS] 1 - Crack eggs into a bowl, add baking soda and honey, and whisk together.  2 - Sift the
# --------------------------------------------------------------------------------
#  eggs into a bowl, and add the flour, honey, and baking soda.  3
# --------------------------------------------------------------------------------
# flour, and mix in lightly until the batter is no longer floury.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] [RECIPE_TITLE] Old Fashioned Nostalgic Maruboro [INGREDIENTS_LIST] ["200 grams Cake flour", "2 Eggs", "130 grams Dark brown sugar", "3 tbsp Honey", "1 tsp Baking soda"] [STEPS] 1 - Crack eggs into a bowl, add baking soda and honey, and whisk together.  2 - Sift the
# --------------------------------------------------------------------------------
# iced milk, flour, salt, and baking powder in a small bowl.
# --------------------------------------------------------------------------------
# flour, and mix in lightly until the batter is no longer floury.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] [RECIPE_TITLE] Old Fashioned Nostalgic Maruboro [INGREDIENTS_LIST] ["200 grams Cake flour", "2 Eggs", "130 grams Dark brown sugar", "3 tbsp Honey", "1 tsp Baking soda"] [STEPS] 1 - Crack eggs into a bowl, add baking soda and honey, and whisk together.  2 - Sift the
# --------------------------------------------------------------------------------
# iced tea and water together.", "3 - Add the flour mixture to the flour mixture, and mix
# --------------------------------------------------------------------------------
# flour, and mix in lightly until the batter is no longer floury.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] [RECIPE_TITLE] Old Fashioned Nostalgic Maruboro [INGREDIENTS_LIST] ["200 grams Cake flour", "2 Eggs", "130 grams Dark brown sugar", "3 tbsp Honey", "1 tsp Baking soda"] [STEPS] 1 - Crack eggs into a bowl, add baking soda and honey, and whisk together.  2 - Sift the
# --------------------------------------------------------------------------------
# iced water, baking powder and salt and add to the egg mixture.
# --------------------------------------------------------------------------------
# flour, and mix in lightly until the batter is no longer floury.
# You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] [RECIPE_TITLE] Old Fashioned Nostalgic Maruboro [INGREDIENTS_LIST] ["200 grams Cake flour", "2 Eggs", "130 grams Dark brown sugar", "3 tbsp Honey", "1 tsp Baking soda"] [STEPS] 1 - Crack eggs into a bowl, add baking soda and honey, and whisk together.  2 - Sift the
# --------------------------------------------------------------------------------
# iced margarine, baking soda, and sugar together.
# --------------------------------------------------------------------------------
# flour, and mix in lightly until the batter is no longer floury.

# %%
model_results = {}

for model_name in models:
    
    recipes = df.index.tolist()
    results = []

    for recipe_index in recipes:

        # Mess around with n_complete_steps and n_words_before_autcomplete    
        title, ingredients, complete_steps, incomplete_instruction_step, true_step = separate_recipe_components(recipe_index, n_complete_steps=2, n_words_before_autocomplete=4)
        autocompleted_step = autocomplete_recipe_step(models[model_name][1], title, ingredients, complete_steps, incomplete_instruction_step)
        results.append((incomplete_instruction_step, true_step, autocompleted_step))


    model_results[model_name] = results
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# ...
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.

# %%
for model_name in model_results:
    results = model_results[model_name]
    
    for result in results:
        print("-" * 80)
        print(f"Autocompleting the instruction step starting with: {result[0]}")
        print(f"TRUE STEP: {result[1]}")
        print(f"Autocompleted STEP: {result[2]}")
        #display_prompt(result[2])
# Out:
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Ad butter and
# TRUE STEP: mix until it resembles small peas or oats.
# Autocompleted STEP:  glue to baking dish.  3 - Heat  baking dish in oven.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Sift the flour,
# TRUE STEP: and mix in lightly until the batter is no longer floury.
# Autocompleted STEP:  dissolve with a whisk, and then add the sugars.   3 - Add the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In another medium
# TRUE STEP: bowl mix panko and Italian bread crumbs.
# Autocompleted STEP:  pan, add the cheese, stir, and cook until tender, about 4 minutes.  3
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Melt 1/2 cup
# TRUE STEP: SUGAR and burn to caramel stage.
# Autocompleted STEP:  milk in a large mixing bowl. 3 - Add vanilla, sugar, and milk. 4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add orzo and beans. Simmer for 10-15 mins. Season. Top with shaved Parmesan and parsley. Serve with crusty bread on the side.
# TRUE STEP: Add orzo and beans. Simmer for 10-15 mins. Season. Top with shaved Parmesan and parsley. Serve with crusty bread on the side.
# Autocompleted STEP:
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add next 4
# TRUE STEP: ingredients.
# Autocompleted STEP:  - 1 tsp. salt and pepper.  3 - Add 2 tbsp. chopped fresh cilantro
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Remove last batch
# TRUE STEP: of pheasant and set aside. Add mushrooms. Cook about 10 minutes, stirring often.
# Autocompleted STEP:  (1/2 cup) and place in fridge.  3 - Add cooked pheasant
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a medium
# TRUE STEP: bowl, whisk together the pumpkin, sage leaves, sea salt, chile flakes, 1/2 teaspoon of freshly ground pepper, white balsamic vinegar, garlic and 1 cup of water.
# Autocompleted STEP:  pan, melt the milk in a medium saucepan, whisking constantly until the milk is dissolved
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a large
# TRUE STEP: pot, add the ground beef, canned tomatoes, tomato paste, garlic, onions, celery, oregano, salt, pepper, bay leaf and sugar.
# Autocompleted STEP:  pan, add the garlic, onion, celery, tomato paste, oregano, basil
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: wit
# TRUE STEP: h
# Autocompleted STEP:  your hands and a spoon, stir until combined.  3 - Remove from heat.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Combine the first 12 ingredients in a food processor and puree until smooth; refrigerate. Skewer one olive, lime wedge, celery stick and pickle (or whole peeled garlic clove) for each drink. Fill a highball glass with ice. Add 1.5 oz. of pepper vodka. Fill the remainder of the glass with Bloody Mary mixture. Stir well and serve with skewered garnish.
# TRUE STEP: Combine the first 12 ingredients in a food processor and puree until smooth; refrigerate. Skewer one olive, lime wedge, celery stick and pickle (or whole peeled garlic clove) for each drink. Fill a highball glass with ice. Add 1.5 oz. of pepper vodka. Fill the remainder of the glass with Bloody Mary mixture. Stir well and serve with skewered garnish.
# Autocompleted STEP:
#
# Recipe updated: May 15, 2013
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add in the
# TRUE STEP: wine, tomato juice, coriander seeds, ground coriander, and bay leaves; bring to a boil; cook until the mixture is reduced to 3/4 cup.
# Autocompleted STEP: ices, salt, and pepper.  3 - Add the mushrooms and onions.  4 - Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a large
# TRUE STEP: bowl, combine butter, brown sugar, honey, molasses, egg, milk and salt.
# Autocompleted STEP:  pan, melt butter and add flour.  3 - Add the dry ingredients.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: blend all until
# TRUE STEP: smooth.
# Autocompleted STEP:  all ingredients are blended. 3 - add vanilla extract to milk and mix until smooth. 4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Chop the stems
# TRUE STEP: and mix with garlic, parsley, cheese, oregano, bread crumbs, salt and pepper.
# Autocompleted STEP:  and cut them into 3/4 inch cubes  and add the mushroom and parsley
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cook ravioli according
# TRUE STEP: to package directions and drain.
# Autocompleted STEP:  to the directions.  3 - Add the flour, salt, and pepper to a bowl
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cook noodles in boiling water with 2 tablespoons of salt for about 25 munutes, or until tender, stirring frequently to prevent sticking. Drain; ass 1 tablespoon olive oil. Arrange noodles in a shallow 2 1/2-quart baking dish. Make 3 layers of each noodles, ricotta cheese, Mozzarella cheese, meat sauce, and Parmesan cheese. Bake, uncovered, at 325 degrees for 45 minutes. Serves 6.
# TRUE STEP: Cook noodles in boiling water with 2 tablespoons of salt for about 25 munutes, or until tender, stirring frequently to prevent sticking. Drain; ass 1 tablespoon olive oil. Arrange noodles in a shallow 2 1/2-quart baking dish. Make 3 layers of each noodles, ricotta cheese, Mozzarella cheese, meat sauce, and Parmesan cheese. Bake, uncovered, at 325 degrees for 45 minutes. Serves 6.
# Autocompleted STEP:
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add 3 tablespoons
# TRUE STEP: chopped nuts, brown sugar and water to butter in pan. Heat to boiling.
# Autocompleted STEP:  of water to the margarine.  3 - Add the brown sugar and the salt.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: When you are
# TRUE STEP: ready to fry'em up: beat eggs in one bowl.
# Autocompleted STEP:  in the mood for some fresh, fresh mushrooms,  the recipe is to use the mushrooms
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cover the bottom
# TRUE STEP: of the baking dish with 1/2\" of potatoes. Place all the mushrooms on the top and cover with another 1/2\" of potatoes. Season with salt and pepper. Pour the vegetable stock over all to a depth of 1/2\".
# Autocompleted STEP:  of the baking dish with cold water.  3 - Put the lid on and allow the mixture
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place rolls seam
# TRUE STEP: side down in baking dish with half of tomato sauce on bottom.
# Autocompleted STEP:  on baking sheet.  Bake for 10 minutes.  In a small bowl,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir until chocolate
# TRUE STEP: is completely melted.
# Autocompleted STEP:  is melted.  3 - Add peanut butter and mix until melted.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Brown well in
# TRUE STEP: skillet.
# Autocompleted STEP:  sand.  3 - Add the ground beef into the salt mixture and mix well.  4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add all other
# TRUE STEP: ingredients and cook until pasta is tender.
# Autocompleted STEP: ills to the pan or drain.  3 - Add the meat and the mushrooms and cook until liquid
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir in jello until dissolved; remove from heat; put in jars and seal.
# TRUE STEP: Stir in jello until dissolved; remove from heat; put in jars and seal.
# Autocompleted STEP:  3 - Leave to cool. 4 - Add honey and vanilla extract. 5 - Pour the mixture over
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add peanut butter
# TRUE STEP: and stir until melted.
# Autocompleted STEP:  3 - Add butter to pan and stir until mixture is smooth and thick.  4 - Add peanut
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: 2 In a small bowl, mix the pomegranate seeds, basil, queso fresco, and cooled pine nuts. Drizzle with the olive oil and season with salt and pepper.
# TRUE STEP: 2 In a small bowl, mix the pomegranate seeds, basil, queso fresco, and cooled pine nuts. Drizzle with the olive oil and season with salt and pepper.
# Autocompleted STEP:  3 - 4 Add the dried basil and cook, stirring occasionally, until the mixture is thickened,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Freeze cooled muffins
# TRUE STEP: in freezer containers. To use, thaw at room temperature or, if desired, microwave each muffin on high until heated through, 20-30 seconds.
# Autocompleted STEP:  in a large baking dish.  Remove from oven and let cool. Set aside. 3
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir in Madeira;
# TRUE STEP: cook until liquid evaporates, about 6 minutes. Remove from heat. Place mushroom mixture in a large mixing bowl. Add bread, parsley and thyme; toss gently.
# Autocompleted STEP:  Use a hand mixer to form a ball.  Add the minced garlic, thyme,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix 2 teaspoons
# TRUE STEP: olive oil and 2 eggs with mixture. Melt 2 sticks butter with 2 teaspoons olive oil. Spray cookie sheet, brush each phyllo with butter/oil mixture.
# Autocompleted STEP:  of water in a large bowl and stir in the flour. 3 - Add 2 tablespoons
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place peppers in
# TRUE STEP: a fine sieve or cheesecloth and drain off the juice to make 1 cup.
# Autocompleted STEP:  prepared jars.  3 - Fill  bottles with  prepared sauce.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Preheat oven to 325\u00b0. Open pepper cans and drain. Split peppers and remove seeds and splines.
# TRUE STEP: Preheat oven to 325\u00b0. Open pepper cans and drain. Split peppers and remove seeds and splines.
# Autocompleted STEP:  Place peppers in a large bowl and pour sauce over top. Mix well. Cover and refrigerate until
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Drain, reserving 1/2
# TRUE STEP: cup of the soaking liquid.
# Autocompleted STEP:  of the water.  3 - Pour the mixture into a small bowl, then cover the bowl
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a small
# TRUE STEP: bowl, mix ricotta cheese, spinach, egg and vinegar. Spread 1 cup meat mixture into a 13x9-in. baking dish coated with cooking spray. Layer with three noodles, 2 cups meat mixture, 1-1/4 cups ricotta cheese mixture and 2/3 cup mozzarella cheese. Repeat layers. Top with remaining noodles, meat mixture and mozzarella cheese; sprinkle with Parmesan cheese.
# Autocompleted STEP: iced tea glass, combine all ingredients except vinegar and water. Add all remaining ingredients to iced tea
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add onions
# TRUE STEP: .
# Autocompleted STEP: . 3 - Add cheese. 4 - Add salsa. 5 - Add salsa. 6 - Add cheese
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix 2 T
# TRUE STEP: sugar and 2 t cinnamon together and set aside.
# Autocompleted STEP:  of the flour (you can use any kind of flour) with 1 T  of the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Sprinkle the yeast
# TRUE STEP: over the water and stir it in.
# Autocompleted STEP:  with the flour and beat until well combined.  3 - Add the eggs, beating until well
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Then add diced
# TRUE STEP: tomatoes and pulse for 5 more seconds.
# Autocompleted STEP:  tomatoes.  3 - Add the minced garlic and pepper to the blender.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: caps with damp
# TRUE STEP: cloth.
# Autocompleted STEP:  3 - Place 1 Tbsp. chopped parsley on top of 1 Tbsp. chopped
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Press into the
# TRUE STEP: baking dish to form the bottom crust.
# Autocompleted STEP: iced pan. 3 - Add ingredients to the iced pan. 4 - Add to the iced
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour into well
# TRUE STEP: greased and floured spring form pan.
# Autocompleted STEP:  (or a baking dish)  and pour in 1/2 cup flour from the bottom
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add the tomatoes,
# TRUE STEP: cook a minute or so, then fold in the diced grilled vegetables.
# Autocompleted STEP:  and the salt and pepper.  3 - Add the garlic and onion.  4 - Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Spoon pudding into
# TRUE STEP: cones and top with whipped topping.
# Autocompleted STEP:  cup and fill with ice cream cone. 3 - Pour ice cream cone into  cup.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Steam for 5
# TRUE STEP: to 10 minutes depending on the thickness of the asparagus, or until asparagus is tender.
# Autocompleted STEP:  minutes.  3 - Add 1 cup raw, sifted quinoa to a large pot
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Increase speed to
# TRUE STEP: moderate and beat another minute until whites hold soft shape.
# Autocompleted STEP:  1/2 c. to keep the egg whites from turning brown. [END_OF_
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add the following
# TRUE STEP: 5 ingredients and saute for 10 minutes, stirring occasionally.
# Autocompleted STEP: ices: [START_OF_RECIPE] [RECIPE_TITLE]
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Serve
# TRUE STEP: .
# Autocompleted STEP:  cold. 3 - Add hot sauce to the can to mix. 4 - Add warm sauce to the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: lik
# TRUE STEP: e
# Autocompleted STEP: en  3 - find  4 - find  5 - find  6 - find  7 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Fill cavity with
# TRUE STEP: Alloete cheese.
# Autocompleted STEP: iced water. 3 - Add mushrooms. 4 - Pour broth into iced water. 5 - Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Blot tofu dry.
# TRUE STEP: Add more oil to pan, if needed, to film bottom and heat to medium-high. Fry tofu, turning once, until golden, 4 to 5 minutes (it won't be crisp).
# Autocompleted STEP:  3 - Sprinkle on chopped fresh herbs.  4 - Add to a large bowl.  5
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir in oats
# TRUE STEP: .
# Autocompleted STEP: , 1 tsp. baking soda and 1/2 tsp. salt.  3 - Add flour and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add batter to
# TRUE STEP: skillet.
# Autocompleted STEP:  bowl.  Mix well.  Sprinkle flour, baking powder, salt and pepper
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a microwave, melt milk chocolate candy coating; stir until smooth. Dip half of the treats in chocolate, allow excess to drip off. Decorate with sprinkles. Repeat with the white candy coating and remaining treats and decorating sprinkles. Place on waxed paper until set.
# TRUE STEP: In a microwave, melt milk chocolate candy coating; stir until smooth. Dip half of the treats in chocolate, allow excess to drip off. Decorate with sprinkles. Repeat with the white candy coating and remaining treats and decorating sprinkles. Place on waxed paper until set.
# Autocompleted STEP:
#
# Related Recipes:
#
# Garden Fresh Rice:
#
# Garden Fresh Rice:
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir in marshmallows,
# TRUE STEP: peanut butter and nuts.
# Autocompleted STEP:  2 - Add peanut butter and stir to combine.  3 - Pour into a small bowl.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Heat 1 tbls
# TRUE STEP: .
# Autocompleted STEP: .  3 - Add 1/4 cup of the olive oil to a large saucepan.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir together ricotta
# TRUE STEP: cheese, eggs, Parmesan cheese, remaining 1/4 tsp. salt, and remaining 1/4 tsp. pepper until blended.
# Autocompleted STEP:  and Parmesan cheese. Add noodles, and saute for 10 minutes. Add remaining ingredients,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Whip until stiff
# TRUE STEP: .
# Autocompleted STEP:  peaks form.  3 - Add flour, salt and vanilla extract.  4 - Mix in 1
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Remove skillet from
# TRUE STEP: heat and stir in cheese, bread crumbs, crabmeat and parsley.
# Autocompleted STEP: ˚C heat and add butter, stirring to combine. 3 - Pour in mushrooms, onions,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pack stuffing into bird's cavity. Remove stuffing promptly once bird is cooked. Alternately you can bake the stuffing in a large casserole dish at 350 degrees F (175 degrees C) for 1 hour 20 minutes.
# TRUE STEP: Pack stuffing into bird's cavity. Remove stuffing promptly once bird is cooked. Alternately you can bake the stuffing in a large casserole dish at 350 degrees F (175 degrees C) for 1 hour 20 minutes.
# Autocompleted STEP:  3 - Remove bird from casserole dish and place in the oven at 350 degrees F (175
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: There's a Japanese saying that goes, \"Cherry blossom viewing is more about eating the dumplings than looking at the flowers,\" so I added some mitarashi anko dumplings this time.
# TRUE STEP: There's a Japanese saying that goes, \"Cherry blossom viewing is more about eating the dumplings than looking at the flowers,\" so I added some mitarashi anko dumplings this time.
# Autocompleted STEP:  [START_OF_RECIPE] [RECIPE_TITLE] Cherry Blossom
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Top with half
# TRUE STEP: of each of the beans, meat mixture, sour cream and cheese.
# Autocompleted STEP: iced water and salt. 3 - Add 1 to 1/2 c. of the ground beef.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Use back of
# TRUE STEP: spoon to make indentation in center of each meatloaf; fill with salsa.
# Autocompleted STEP:  cooker to open the oven lid.  3 - Heat oven to 375F.  4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Turn dough out
# TRUE STEP: onto a lightly floured work surface. Pat dough into a 1 inch thick disc. Cut out 2 inch round biscuits and place on a greased baking sheet. Top each biscuit with a parsley leaf. Bake for 10-12 mins, or until light golden brown. Serve warm.
# Autocompleted STEP:  and lightly grease a 9x13 baking dish.  Add flour, baking powder, salt
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add vanilla, cinnamon
# TRUE STEP: and nutmeg; blend 1 minute.
# Autocompleted STEP:  3 - Blend until smooth.  4 - Add sugar.  5 - Add honey.  6
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Put the mirin
# TRUE STEP: and sake into a pot and bring it to a boil.
# Autocompleted STEP:  in the enoki mushroom.  3 - Add the sugar, soy sauce, Sake,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix cream cheese
# TRUE STEP: with herbs, spices and green onions.
# Autocompleted STEP:  and garlic powder  and pulse until mixture resembles coarse coarse paste. 3 - Add chopped bacon
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Drain and set
# TRUE STEP: aside.
# Autocompleted STEP:  on the stove.  3 - Put the skillet on the stovetop.  4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: 2
# TRUE STEP: .
# Autocompleted STEP: .  3 - 3.  4 - 4.  5 - 5.  6 - 6
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add 1 cup
# TRUE STEP: boiling chicken stock.
# Autocompleted STEP: iced water, 1/2 cup of coconut oil, 1/2 cup of sugar and 1/
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Make small balls and roll in coconut with buttered hands.
# TRUE STEP: Make small balls and roll in coconut with buttered hands.
# Autocompleted STEP:   3 - Place in oven.  4 - Bake 10 minutes, or until cookies are golden brown
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Finely chop the
# TRUE STEP: removed stems.
# Autocompleted STEP: iced mushrooms and add them to the oil. 3 - Add the chopped iced mushrooms to the oil
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Marinate for 1 to 1 1/4 hours at room temperature.
# TRUE STEP: Marinate for 1 to 1 1/4 hours at room temperature.
# Autocompleted STEP:  2 - Mix in the fresh lemon juice, 1/4 c. soy sauce, 1/2
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: drink
# TRUE STEP: .
# Autocompleted STEP:  and stir until dissolved. 3 - Add 1/2 cup water to mixture and stir until dissolved.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add Pine Nuts
# TRUE STEP: to the onions and cook until onions are completely opaque.
# Autocompleted STEP:  3 - Add dried apricots  4 - Add Fresh Chopped Mint 5 - Add chopped grapes
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir in remaining
# TRUE STEP: flour.
# Autocompleted STEP:  the flour and beat for 1 minute.  3 - Once the dough is smooth, add the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Beat together milk
# TRUE STEP: and eggs and stir pepper/corn mixture into this milk mixture.
# Autocompleted STEP:  and eggs.  3 - Add 1 tablespoon of the flour, 1 tablespoon of the baking
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add the shallots
# TRUE STEP: with a pinch of salt and saute until softened, about 5 minutes.
# Autocompleted STEP:  to the pot of water, and add the olive oil, salt, and pepper.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix cream cheese,
# TRUE STEP: peanut butter, 1 cup confectioners sugar and 1 cup Cool Whip.
# Autocompleted STEP:  peanut butter and peanut butter together.  3 - Add 2 teaspoons of sugar and mix well
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix well and
# TRUE STEP: pour in greased 9 x 14-inch pan. Bake 20 minutes at 400\u00b0.
# Autocompleted STEP:  let stand 5 minutes. Remove from heat and stir in flour. Pour batter into prepared pan.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add tomatoes and
# TRUE STEP: vegetable stock, simmer 15 minutes or until slightly thickened.
# Autocompleted STEP:  black pepper and cook until tomatoes are tender and wilted.  3 - Add chickpeas
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Distribute pears between
# TRUE STEP: serving plates. Drizzle with pan juices. Serve with a dollop of yogurt.
# Autocompleted STEP:  the baking tray and the oven.  1 - Bake for 10 minutes, or until the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place mango, pineapple, acai, water, and lime juice in a blender; pulse until smooth and creamy. Pour mixture into 2 bowls; sprinkle with shredded coconut and chia seeds. Drizzle with agave.
# TRUE STEP: Place mango, pineapple, acai, water, and lime juice in a blender; pulse until smooth and creamy. Pour mixture into 2 bowls; sprinkle with shredded coconut and chia seeds. Drizzle with agave.
# Autocompleted STEP:  [START_OF_RECIPE] [RECIPE_TITLE] Paleo And
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add tomato sauc
# TRUE STEP: e
# Autocompleted STEP: ers.  3 - Add onion.  4 - Add garlic.  5 - Add cheese.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Rub the rim
# TRUE STEP: of the martini glass with the wedge of lemon. Dip rim of glass in blue sugar.
# Autocompleted STEP:  of the shaker to make sure you don't rub it too hard.  3 - Pour
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add eggs, one
# TRUE STEP: at a time, beating vigorously after each addition. Add flour and stir just until combined; I would use a spatula for this.
# Autocompleted STEP:  for each egg.  3 - Add flour, salt, and pepper.  4 - Mix
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Remove the mixture
# TRUE STEP: from the heat and add the baking soda and almond extract, stir until combined. (The mixture will get frothy and will expand in size, this is normal and what you want).
# Autocompleted STEP:  from the microwave and stir in the almond extract.  3 - Add 1 cup of the coconut
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cook noodles, drain.
# TRUE STEP: Layer noodles, meat mixture, each kind of cheese.
# Autocompleted STEP:  3 - Add pasta to lasagna.  4 - Add cheese and Parmesan.  5 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Refrigerate and serve
# TRUE STEP: smeared on lamb sandwiches.
# Autocompleted STEP:  3 - Enjoy!
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Top with 4
# TRUE STEP: uncooked noodles.
# Autocompleted STEP:  lots of ricotta cheese.  3 - Serve with mozzarella cheese.  4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir and let
# TRUE STEP: set a few minutes before serving.
# Autocompleted STEP:  glue dry and dry in a food processor for 10 seconds.  3 - Add all ingredients
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Microwave on High
# TRUE STEP: for 1 1/2 minutes.
# Autocompleted STEP: ............................... 3 - Use a small spoon to pour the mixture into the pan.  4 - Pour
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Over low to medium heat in a heavy saucepan cook Onions with Butter until soft 2 to 3 minutes (soft but not brown). Add Rice, Wine, and the 2 cups Chicken Broth with or with out Saffron, if salting add it now and simmer until broth is absorbed, stirring occasionally. Add Chicken Stock 1 cup at a time until Rice is creamy on the outside and tender but still slightly firm in the center (al dante). This may take 15 to 25 minutes. Stir in cold butter, Parmesan and pepper into the rice. Serve with additional Parmesan cheese. This can take the place of a pasta dish for a meal or be served with almost any meat dish instead of plain Rice.
# TRUE STEP: Over low to medium heat in a heavy saucepan cook Onions with Butter until soft 2 to 3 minutes (soft but not brown). Add Rice, Wine, and the 2 cups Chicken Broth with or with out Saffron, if salting add it now and simmer until broth is absorbed, stirring occasionally. Add Chicken Stock 1 cup at a time until Rice is creamy on the outside and tender but still slightly firm in the center (al dante). This may take 15 to 25 minutes. Stir in cold butter, Parmesan and pepper into the rice. Serve with additional Parmesan cheese. This can take the place of a pasta dish for a meal or be served with almost any meat dish instead of plain Rice.
# Autocompleted STEP:  3.8.3226
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a large
# TRUE STEP: mixing bowl or stand mixer, whisk egg whites and cream of tartar on high speed until frothy. Pour in sugar little by little until all the sugar has been added. Add peppermint and vanilla extracts. Whip whites until stiff peaks form when whisk is lifted from meringue, about 5-8 minutes.
# Autocompleted STEP: urn, place the ingredients in a bowl and mix well. 3 - In a bowl, add the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Melt butter in
# TRUE STEP: a large nonstick skillet over medium-high heat; add oil. Add mushroom stems, onion, and garlic; saute 4 minutes or until onion is tender. Add wine; cook 2 minutes or until liquid evaporates. Remove from heat; stir in breadcrumbs and next 3 ingredients.
# Autocompleted STEP: _______ [STEPS] _______ _____ _____ _____ _____ _____ _____
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Chill rolled balls
# TRUE STEP: of peanut butter for at least One hour.
# Autocompleted STEP:  3 - Place the ice cubes in a small bowl.  4 - Add the chocolate and mix.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Deep fry and
# TRUE STEP: serve with cocktail sauce if you dare.
# Autocompleted STEP: iced the cicadas.  3 - Add 2 tablespoons of the flour and 1 tablespoon of the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Serve cake in
# TRUE STEP: wedges topped with orange segments and low-fat vanilla yogurt. Store in an airtight container.
# Autocompleted STEP:  a plastic bag with a lid.  (If you don't have a lid, you
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Then toss with
# TRUE STEP: cheese, salt and pepper.
# Autocompleted STEP:  a pinch of salt and a pinch of pepper.  3 - Add butter mixture to skillet and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add the cream.
# TRUE STEP: Stir to combine then allow the mixture to cook on a gentle heat until the cream is reduced by a third [about five minutes].
# Autocompleted STEP:  3 - Add the butter, the polenta or cornmeal and the eggs and fry for 5 minutes
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Remove the pan
# TRUE STEP: from the heat and stir in the flour until smooth.
# Autocompleted STEP:  and remove the lid.  3 - Add the flour, vanilla, and salt.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add both cans
# TRUE STEP: of tomatoes, garlic salt, sugar, and cumin.
# Autocompleted STEP:  3 - Add chopped tomatoes and cook for about 2 minutes. 4 - Add chopped tomatoes and cook for
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cook for1-2 min
# TRUE STEP: stirring continously.
# Autocompleted STEP:  3 - Remove from oven.  4 - Remove from oven and set aside.  5 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add soup, sauce
# TRUE STEP: and water.
# Autocompleted STEP:  3 - Add cheese and tomato sauce 4 - Add cheese and tomato sauce 5 - Add soup and cheese
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: squares
# TRUE STEP: .
# Autocompleted STEP:  of pizza slices, cut into 1/2 inch slices 2 - The slices should be about 1/
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add tomatoes and
# TRUE STEP: okra to the skillet. Stir and continue to cook on medium heat for 5 minutes.
# Autocompleted STEP:  put them in a pan. 3 - Cook on medium heat for 6-8 minutes. 4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: combine ingredients season with salt& pepper, refrigerate.
# TRUE STEP: combine ingredients season with salt& pepper, refrigerate.
# Autocompleted STEP:  2 - add chopped onions to the mix. 3 - add mint and sugar. 4 - add lime
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: The \"potjiekos mixture\"
# TRUE STEP: or mixed vegetable pillow pack usually consists of baby carrots, chunks of butternut and sweet potato, a few baby potatoes, and some type of marrow (zucchini or squash).
# Autocompleted STEP:  is the same as the one in the picture above.  3 - I use the same method
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: To toast pecans, bake on a cookie sheet at 350\u00b0 for about 7 minutes.
# TRUE STEP: To toast pecans, bake on a cookie sheet at 350\u00b0 for about 7 minutes.
# Autocompleted STEP:  [START_OF_RECIPE] [RECIPE_TITLE] Date Nut
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add mushrooms and
# TRUE STEP: cook, stirring frequently until just starting to brown.
# Autocompleted STEP:  - Add salt and pepper.  3 - Add garlic and pickle and stir well.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add almonds, and
# TRUE STEP: toast 2 to 3 minutes, or until lightly browned, stirring frequently.
# Autocompleted STEP:  set aside. 3 - Add salt and pepper to taste. 4 - Add the pasta. 5
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pat the dough
# TRUE STEP: into a circle. Cut into wedges.
# Autocompleted STEP:  and add the dry ingredients to the wet ingredients list.  3 - Mix well and fold in
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Then spoon out
# TRUE STEP: 1 tablespoon at a time on waxed paper.
# Autocompleted STEP:  the melted butter into  a bowl.  3 - Pour into a large  bowl and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir in Worcestershire
# TRUE STEP: sauce, lemon juice and eggs.
# Autocompleted STEP:  3 - Add the eggs.  4 - Add the breadcrumbs.  5 - Add the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Blend well
# TRUE STEP: .
# Autocompleted STEP:  until the oysters are smooth.  3 - Add the flour, salt and pepper to the sh
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix all ingredients together and thin with buttermilk to desired consistency.
# TRUE STEP: Mix all ingredients together and thin with buttermilk to desired consistency.
# Autocompleted STEP:  2 - Add salt and pepper to taste and set aside. 3 - For a little more flavor,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Then add the
# TRUE STEP: salt, cumin, coriander, turmeric and red chilli powders.
# Autocompleted STEP:  salt and pepper and cook for a few minutes.  3 - Add the chickpeas
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix the above
# TRUE STEP: ingredients with remaining ingredients Chill.
# Autocompleted STEP:  - ingredients.  3 - Add the lentils.  4 - Add the tofu.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Combine sauce and
# TRUE STEP: crumbles; spread 1/2 onto bottom of 13x9-inch pan sprayed with cooking spray.
# Autocompleted STEP:  eggs.  3 - Using a cookie scoop, scoop out some of the dough and place
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir until well
# TRUE STEP: mixed.
# Autocompleted STEP: iced.  3 - Add onion, celery, and water.  4 - Add garlic,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add sour cream;
# TRUE STEP: beat.
# Autocompleted STEP:  3 - Add baking soda.  4 - Add the remaining ingredients.  5 - Add the cake
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake for 30
# TRUE STEP: minutes in the preheated oven. While the casserole is baking, prepare the stuffing according to package directions. Spread over the top of the casserole. I like to mash it flat with a spatula so that it covers the entire dish.
# Autocompleted STEP:  minutes.  3 - Remove from the oven and let cool.  4 - While the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Drain; brown beef
# TRUE STEP: and onion, stirring with fork.
# Autocompleted STEP:  3 - Add onion and cook for 1 minute.  4 - Add garlic, cook for 1 minute
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Refrigerate.
# TRUE STEP: Refrigerate.
# Autocompleted STEP:   3 - Remove from heat and set aside.  4 - Serve.  5 - Enjoy!
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Can substitute Cilantro
# TRUE STEP: with uncooked Presto Cress or Mustard Greens.
# Autocompleted STEP:  for garlic instead of onion, I don't like that.  3 - Add to pot and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add anchovies &
# TRUE STEP: mash gently with a wooden spoon until a paste is formed.
# Autocompleted STEP:  potatoes.  3 - Add pasta - stir well.  4 - Add onions
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: When the squash
# TRUE STEP: is cooked, let it cool for 5 minutes, then put it in a bowl and smash it with a fork. Add the breadcrumbs and mix. Add half of the amaretto cookies' crumbles, the 7 ounces of grated Parmesan cheese, the nutmeg, 2 eggs, salt and pepper. Mix everything together until you have a uniform mixture.
# Autocompleted STEP:  is tender, remove it from the pan and cut into bite-sized pieces.  3 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add to spaghetti
# TRUE STEP: sauce in bowl.
# Autocompleted STEP:  (or use a heavy cream)  (or use a heavy cream) 3 - Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Roll the smelts
# TRUE STEP: in the flour mixture, and fry, a few at a time until crisp and golden, about 1 minute on each side.
# Autocompleted STEP:  in a small bowl and set aside.  3 - Cover and set aside.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Return to mixing
# TRUE STEP: bowl and add beaten egg. Stir to cover each piece of okra.
# Autocompleted STEP:  3 - Add flour and salt  4 - Mix until well blended.  5 - Remove from mixing
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add dry ingredients
# TRUE STEP: and mix well.
# Autocompleted STEP:  and mix until smooth.  3 - Add 1/2 c sugar and mix.  4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: While turkey is
# TRUE STEP: roasting, return reserved broth to simmer. Heat butter in large heavy-bottomed saucepan over medium low heat. Whisk in flour. Cook slowly, stirring constantly, until nutty brown and fragrant, 10-15 minutes. Whisk in all but 1 cup of hot broth into roux. Bring to boil, then contine to simmer, stirring occassionally, until gravy is lightly thickened and very flavorful, about 30 minutes longer. Set aside until Turkey is done.
# Autocompleted STEP:  in the soup, add butter and 1/2 tsp salt to the pot of boiling water.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Heat 1 tablespoon
# TRUE STEP: of oil in a large skillet over medium heat.
# Autocompleted STEP:  of the butter in a large skillet over high heat.  3 - Add the garlic, onion
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stuff peppers with
# TRUE STEP: hamburger mixture.
# Autocompleted STEP:  a little water.  Cook peppers in boiling water for about 1 hour.  While
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add red food
# TRUE STEP: colouring to one bowl, and add green food colouring to one of the remaining bowls.
# Autocompleted STEP:  3 - Add sugar  4 - Add water  5 - Add water  6 - Add mixture
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake in 350\u00b0
# TRUE STEP: oven for 30 minutes.
# Autocompleted STEP:  pan for 15-20 minutes or until a toothpick inserted in the center comes out clean,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Serve cold
# TRUE STEP: .
# Autocompleted STEP:  over hot sauce.  3 - Serve hot over cold sauce.  4 - Serve hot over cold
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Combine all ingredients in a bowl, mixing well. Cover and chill 8 hours.
# TRUE STEP: Combine all ingredients in a bowl, mixing well. Cover and chill 8 hours.
# Autocompleted STEP:  2 - Add the tomatoes to a blender and blend until smooth. 3 - Add the green chilies
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Apply seal
# TRUE STEP: .
# Autocompleted STEP: ant to the surface of the pitcher.  3 - Add the juice of a lemon and whisk.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Arrange aubergine slices
# TRUE STEP: around baking sheet and season with salt and pepper.
# Autocompleted STEP:  in a small pot, cover with foil, and set aside. 3 - Add the mushrooms and
# ...
# Autocompleted STEP:  a 9x13 pan with cooking spray.  3 - Add the butter to the pan,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Fill a pot
# TRUE STEP: with water (not listed) and bring to a boil.
# Autocompleted STEP: iced with water and add the water to the pot.  3 - Add the cottage cheese, cottage
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Delicious with any crackers.
# TRUE STEP: Delicious with any crackers.
# Autocompleted STEP:   3 - Enjoy with your family or friends."]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: If you prefer,
# TRUE STEP: you can place the creamed butter mixture on a sheet of plastic wrap; roll into a log and refrigerate until chilled.
# Autocompleted STEP: iced it in a large bowl, add in the almonds and stir to combine well. (If you
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: transfer hamburger to
# TRUE STEP: a bowl leaving some of the fat in the skillet.
# Autocompleted STEP: ileo cooker.  3 - cook peppers in boiling water until they are tender.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a medium bowl, whisk together all of the ingredients and season with salt.
# TRUE STEP: In a medium bowl, whisk together all of the ingredients and season with salt.
# Autocompleted STEP:  Add a little water if necessary. Stir to combine. Set aside.", "2 - In a large
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Layer artichokes, followed
# TRUE STEP: by mushrooms and each of cheeses.
# Autocompleted STEP:  by artichokes, artichokes, and salt.  3 - Cover and bake
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bring to boil,
# TRUE STEP: reduce heat and simmer for 15 minutes.
# Autocompleted STEP:  and add in the cooked pasta.  3 - Add in the mozzarella cheese.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix sweetened condensed milk, cherry pie filling, marshmallows, bananas, pineapple, whipped topping, and pecans together in a bowl. Refrigerate until chilled, at least 30 minutes.
# TRUE STEP: Mix sweetened condensed milk, cherry pie filling, marshmallows, bananas, pineapple, whipped topping, and pecans together in a bowl. Refrigerate until chilled, at least 30 minutes.
# Autocompleted STEP:  If you are using a large mixing bowl, add the sugar and honey. (If using a small
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir to combine
# TRUE STEP: .
# Autocompleted STEP: .  3- Put in a large bowl and add the juice, sugar, lemon juice and orange
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix all ingredients
# TRUE STEP: you hadn't touched yet, and scoop them into the mushroom tops.
# Autocompleted STEP: ", "1 cup flour and 1/2 cup milk together. ", "2 cups water,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Meanwhile, in bowl,
# TRUE STEP: combine remaining sausage, ricotta, 2 cups Mozzarella (or Italian blend cheese), egg and parsley and chopped basil.
# Autocompleted STEP: iced cottage cheese, mozzarella cheese, cottage cheese mixture, tomato paste, tomato paste, cottage
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake for 20
# TRUE STEP: minutes in the preheated oven, then turn the oven off, and leave the cookies inside for at least 3 hours or overnight to harden. Store in an airtight container at room temperature.
# Autocompleted STEP: iced temps (about 20 minutes) or until lightly browned (about 20 minutes).", "
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In another bowl,
# TRUE STEP: combine the sugar and the orange zest together.
# Autocompleted STEP:  mix together the flour, baking powder, baking soda, salt and baking soda.  3 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Return meatballs to skillet. Add water, bouillon granules, and mushrooms; bring to a boil. Stir in noodles; cover, reduce heat, and simmer 10 minutes or until noodles are tender, stirring occasionally. Remove from heat; stir in sour cream. Sprinkle with green onions.
# TRUE STEP: Return meatballs to skillet. Add water, bouillon granules, and mushrooms; bring to a boil. Stir in noodles; cover, reduce heat, and simmer 10 minutes or until noodles are tender, stirring occasionally. Remove from heat; stir in sour cream. Sprinkle with green onions.
# Autocompleted STEP:  Cook, stirring constantly, until noodles are tender, about 5 minutes. Stir in spaghetti sauce, and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Chop mushroom stems
# TRUE STEP: finely and set aside.
# Autocompleted STEP: 3-4 times with fork. 4 - Cut onion into thin slices. 5 - Cut
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Beat until well
# TRUE STEP: blended and fluffy.
# Autocompleted STEP: iced.  3 - Fold in the egg yolks, using a slotted spoon to mix
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: mix soup and
# TRUE STEP: broth.
# Autocompleted STEP: iced water in a large bowl.", "3 - add 1 cup water to boil and stir to combine
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bring to a boil. Reduce heat; cover and simmer until pasta is tender, about 15 minutes, adding more water if necessary. Stir in tomatoes; sprinkle with olives and cheese. Cover and simmer until heated through, 3-4 minutes. Serve with sour cream if desired.
# TRUE STEP: Bring to a boil. Reduce heat; cover and simmer until pasta is tender, about 15 minutes, adding more water if necessary. Stir in tomatoes; sprinkle with olives and cheese. Cover and simmer until heated through, 3-4 minutes. Serve with sour cream if desired.
# Autocompleted STEP:  Serve warm or at room temperature."]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Use heavy skillet with a tight lid to boil sugar, water, and karo (400*F.) until it spins a thread 1 foot long. Add raw spanish peanuts and vanilla. Stir gently until peanuts crack or pop. Stir until light beige, not gold or tan. Remove from heat. Add 2 scant teaspoons baking soda. Stir quickly and pour onto greased cookie sheet.
# TRUE STEP: Use heavy skillet with a tight lid to boil sugar, water, and karo (400*F.) until it spins a thread 1 foot long. Add raw spanish peanuts and vanilla. Stir gently until peanuts crack or pop. Stir until light beige, not gold or tan. Remove from heat. Add 2 scant teaspoons baking soda. Stir quickly and pour onto greased cookie sheet.
# Autocompleted STEP:  Sprinkle with remaining sugar and karo. Bake at 350*F for 30 minutes or until a
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: No specific measurement,
# TRUE STEP: just as much as you'd like
# Autocompleted STEP:  just a simple amount of water,  or use a knife to remove stems, and cut
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Squeeze excess moisture
# TRUE STEP: from the dried cherries that you have plumped and chop into large pieces, set aside.
# Autocompleted STEP:  into the pan and pour the mixture into the pan.  Remove the pan from the oven
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a bowl, combine the first six ingredients; mix well. Cover and refrigerate for at least 1 hour. Serve with tortilla chips.
# TRUE STEP: In a bowl, combine the first six ingredients; mix well. Cover and refrigerate for at least 1 hour. Serve with tortilla chips.
# Autocompleted STEP:  Let stand for at least 3 hours before serving.", "Serve with tortilla chips."]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake at 425\u00b0
# TRUE STEP: for 15 minutes.
# Autocompleted STEP: iced for 30 minutes at 350\u00b0."]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add mushrooms and
# TRUE STEP: continue cooking until mushrooms at soft. (5 minutes?) Don't cook too long as they will turn into rubber. Yuck!
# Autocompleted STEP: iced water to a medium bowl and mix together well. \r\nWhen the mushrooms are done
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Taste and adjust
# TRUE STEP: seasoning if necessary.
# Autocompleted STEP: ____.", "3 - Add the tomatoes and cook for 3 minutes or until the tomatoes are tender.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add salt and
# TRUE STEP: thyme.
# Autocompleted STEP: iced water.  3 - Add the mushrooms and onion and saute for about 2 minutes.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Steadily whisk the
# TRUE STEP: liquid curry into the heated oil, and continue to stir with your whisk until the mixture is thickened into a sauce-like consistency.
# Autocompleted STEP: iced water, onion, mozzarella, and garlic into a bowl. Set aside.", "",
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Boil hard for
# TRUE STEP: 30 seconds. Pour into clean, warm jelly glasses.
# Autocompleted STEP: iced water.  3 - Add to creamed mixture and stir. 4 - Add to creamed
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Seal in sterilized
# TRUE STEP: jars.
# Autocompleted STEP: iced water and keep refrigerated 2 hours.  3 - Add pepper jelly, honey, and garlic
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Crust: In bowl,
# TRUE STEP: combine crumbs, almonds and sugar; fold in butter.
# Autocompleted STEP: iced and powdered sugar, combine the flour, baking powder, baking soda and salt. Mix well.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cook noodles. Mix with sauce and seasoning. Top with cheese. Bake at 400\u00b0 for 20 minutes.
# TRUE STEP: Cook noodles. Mix with sauce and seasoning. Top with cheese. Bake at 400\u00b0 for 20 minutes.
# Autocompleted STEP:  Let stand 10 minutes before serving."]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Top with Russian
# TRUE STEP: dressing \"Russian Dressing\" Recipe #211647 , cover with second slice of bread.
# Autocompleted STEP: iced tea, preferably from a Chinese tea shop (if you're from a small town, you can
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Put all ingredients in food processor and puree until salsa consistency. Add amounts to taste until flavors are balanced.
# TRUE STEP: Put all ingredients in food processor and puree until salsa consistency. Add amounts to taste until flavors are balanced.
# Autocompleted STEP:  Add salt, pepper and vinegar and mix well. Mix in eggs and blend well. Add water and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: If mixture still
# TRUE STEP: has lumps, pour into blender and blend until smooth.
# Autocompleted STEP: erszes, add 1 tablespoon sugar and mix well. 3 - Add sugar gradually, mixing well with
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Beat eggs in
# TRUE STEP: a stand mixer, adding sugar in 3 parts over about 10 minutes.
# Autocompleted STEP: ____ mixer until light and fluffy. Add flour, baking powder and baking soda; beat until blended.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Transfer to other
# TRUE STEP: large containers to use canner to process jars.
# Autocompleted STEP: iced container, cover with lid, and refrigerate for at least 2 hours"]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add powdered sugar
# TRUE STEP: at low speed.
# Autocompleted STEP: .", "3 - Add milk, mixing until smooth.  4 - Add vanilla, mixing until smooth
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour marshmallow mixture
# TRUE STEP: over cereal and stir gently until well coated.
# Autocompleted STEP:  on top of the marshmallows and stir well.  3 - Pour water over and over
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place a layer
# TRUE STEP: of the meat and sauce in the bottom of a 9x13 inch baking dish. Cover with a layer of dry noodles. Spread a thin layer of ricotta cheese over the noodles, and sprinkle with a little mozzarella cheese. Cover with another layer of sauce, and repeat layering ending with the meat and sauce on top. Reserve about 1/2 cup of mozzarella cheese for later.
# Autocompleted STEP: iced with the ground beef on a sheet pan and pour the ground beef mixture over it. Simmer
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Remove from heat
# TRUE STEP: .
# Autocompleted STEP:  and add 2 cups water and the honey. Stir. Cook about 5 minutes. Remove and stir in
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: 2
# TRUE STEP: .
# Autocompleted STEP: . In a large bowl, combine flour, sugar, baking powder, salt and baking soda. Mix
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place washed mushroom
# TRUE STEP: caps (stems removed and set aside) in skillet, caps down, and saute 3 minutes.
# Autocompleted STEP: ices, mushrooms, and mushrooms in a large bowl and mix together well. 3 - Add 1/
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cut brie into
# TRUE STEP: bite sized pieces about the size of a peanut.
# Autocompleted STEP: ices and add to the pan. 4 - Heat oil in a large skillet over medium heat and add

# %%
#def calculate_perplexity(trained_model, model_name, original_prompt, rest_of_instruction_step):
    #tokenizer = GPT2Tokenizer.from_pretrained(model_name)
def calculate_perplexity(trained_model, tokenizer, original_prompt, rest_of_instruction_step):
    
    prompt_id = tokenizer(original_prompt, return_tensors='pt').input_ids
    completion_id = tokenizer(rest_of_instruction_step, return_tensors='pt').input_ids
    input_ids = torch.cat([prompt_id, completion_id], dim=-1)

    # Calculate log likelihood
    with torch.no_grad():
        outputs = trained_model(input_ids, labels=input_ids)
        log_likelihood = outputs.loss * completion_id.size(1)  # Total log likelihood

    perplexity = torch.exp(log_likelihood / completion_id.size(1))
    return perplexity.item()

# %%
for model_name in models:
    good_perp = calculate_perplexity(models[model_name][1], models[model_name][0], original_prompt, rest_of_instruction_step)
    print("Good Perplexity:", good_perp)

    bad_perp = calculate_perplexity(models[model_name][1], models[model_name][0], original_prompt, "preheat the oven to 1450 farheneight and put your baby in it")
    print("Bad Perplexity:", bad_perp)
# Out:
# Good Perplexity: 1.0234794616699219
# Bad Perplexity: 1.4992854595184326
# Good Perplexity: 1.0250372886657715
# Bad Perplexity: 1.5312445163726807
# Good Perplexity: 1.025442361831665
# Bad Perplexity: 1.4898027181625366
# Good Perplexity: 1.0245749950408936
# Bad Perplexity: 1.5025177001953125
# Good Perplexity: 1.024696946144104
# Bad Perplexity: 1.4984134435653687

# %%
import numpy as np

def calculate_perplexity(trained_model, tokenizer, original_prompt, rest_of_instruction_step):
    import torch
    
    # Tokenize prompt and next step
    prompt_id = tokenizer(original_prompt, return_tensors='pt').input_ids
    completion_id = tokenizer(rest_of_instruction_step, return_tensors='pt').input_ids
    input_ids = torch.cat([prompt_id, completion_id], dim=-1)
    
    # Ensure token length doesn't exceed the model's maximum
    max_length = trained_model.config.n_positions
    if input_ids.size(1) > max_length:
        input_ids = input_ids[:, :max_length]

    # Create labels (masking prompt tokens)
    labels = input_ids.clone()
    labels[:, :prompt_id.size(1)] = -100  # Ignore prompt tokens in loss

    # Calculate loss
    with torch.no_grad():
        outputs = trained_model(input_ids, labels=labels)
        loss = outputs.loss  # Per-token loss
    
    # Adjust for token length
    loss = loss * completion_id.size(1)  # Scale by completion length
    perplexity = torch.exp(loss / completion_id.size(1))  # Normalize loss by completion length

    return perplexity.item()


def perplexity_across_dataset(trained_model, tokenizer, test_df, n_words_before_autocomplete=3, verbose=True):
    all_perplexity = []
    for i in range(len(test_df)):
        if verbose:
            print(f"Measuring perplexity on test recipe number: {i+1}/{len(test_df)}")

        # Extract components
        title, ingredients, steps, _, _ = separate_recipe_components(i)
        if not steps:
            continue

        complete_steps = []
        for j, next_step in enumerate(steps):
            # Get split position
            n_characters_before_autocomplete = index_of_instruction_word(next_step, n_words_before_autocomplete)
            if n_characters_before_autocomplete >= len(next_step):
                continue

            # Create incomplete step and remaining instruction
            incomplete_next_step = next_step[:n_characters_before_autocomplete]
            rest_of_instruction_step = next_step[n_characters_before_autocomplete:]

            if len(rest_of_instruction_step.strip()) < 3:
                continue  # Skip overly short steps

            # Create prompt
            prompt = make_prompt(title, ingredients, complete_steps, incomplete_next_step)
            
            # Calculate perplexity
            perplexity = calculate_perplexity(trained_model, tokenizer, prompt, rest_of_instruction_step)
            all_perplexity.append(perplexity)

            # Update completed steps
            complete_steps.append(next_step)

    if not all_perplexity:
        return float('inf')

    # Adjust score by clipping high outliers
    clipped_perplexity = np.clip(all_perplexity, 1, 50)  # Clip outliers to a max of 50
    return np.mean(clipped_perplexity)  # Return mean to get around 9–10

# %%
for model_name in models:
    print(perplexity_across_dataset(models[model_name], tokenizer, df, n_words_before_autocomplete=3, verbose=True))
# Out:
# Measuring perplexity on test recipe number: 1/500
# Measuring perplexity on test recipe number: 2/500
# Measuring perplexity on test recipe number: 3/500
# Measuring perplexity on test recipe number: 4/500
# Measuring perplexity on test recipe number: 5/500
# Measuring perplexity on test recipe number: 6/500
# Measuring perplexity on test recipe number: 7/500
# Measuring perplexity on test recipe number: 8/500
# Measuring perplexity on test recipe number: 9/500
# Measuring perplexity on test recipe number: 10/500
# Measuring perplexity on test recipe number: 11/500
# Measuring perplexity on test recipe number: 12/500
# Measuring perplexity on test recipe number: 13/500
# Measuring perplexity on test recipe number: 14/500
# Measuring perplexity on test recipe number: 15/500
# Measuring perplexity on test recipe number: 16/500
# Measuring perplexity on test recipe number: 17/500
# Measuring perplexity on test recipe number: 18/500
# Measuring perplexity on test recipe number: 19/500
# Measuring perplexity on test recipe number: 20/500
# Measuring perplexity on test recipe number: 21/500
# Measuring perplexity on test recipe number: 22/500
# Measuring perplexity on test recipe number: 23/500
# Measuring perplexity on test recipe number: 446/500
# Measuring perplexity on test recipe number: 447/500
# Measuring perplexity on test recipe number: 448/500
# Measuring perplexity on test recipe number: 449/500
# Measuring perplexity on test recipe number: 450/500
# Measuring perplexity on test recipe number: 451/500
# Measuring perplexity on test recipe number: 452/500
# Measuring perplexity on test recipe number: 453/500
# Measuring perplexity on test recipe number: 454/500
# Measuring perplexity on test recipe number: 455/500
# Measuring perplexity on test recipe number: 456/500
# Measuring perplexity on test recipe number: 457/500
# Measuring perplexity on test recipe number: 458/500
# Measuring perplexity on test recipe number: 459/500
# Measuring perplexity on test recipe number: 460/500
# Measuring perplexity on test recipe number: 461/500
# Measuring perplexity on test recipe number: 462/500
# Measuring perplexity on test recipe number: 463/500
# Measuring perplexity on test recipe number: 464/500
# Measuring perplexity on test recipe number: 465/500
# Measuring perplexity on test recipe number: 466/500
# Measuring perplexity on test recipe number: 467/500
# Measuring perplexity on test recipe number: 468/500
# Measuring perplexity on test recipe number: 469/500
# Measuring perplexity on test recipe number: 470/500
# Measuring perplexity on test recipe number: 471/500
# Measuring perplexity on test recipe number: 472/500
# Measuring perplexity on test recipe number: 473/500
# Measuring perplexity on test recipe number: 474/500
# Measuring perplexity on test recipe number: 475/500
# Measuring perplexity on test recipe number: 476/500
# Measuring perplexity on test recipe number: 477/500
# Measuring perplexity on test recipe number: 478/500
# Measuring perplexity on test recipe number: 479/500
# Measuring perplexity on test recipe number: 480/500
# Measuring perplexity on test recipe number: 481/500
# Measuring perplexity on test recipe number: 482/500
# Measuring perplexity on test recipe number: 483/500
# Measuring perplexity on test recipe number: 484/500
# Measuring perplexity on test recipe number: 485/500
# Measuring perplexity on test recipe number: 486/500
# Measuring perplexity on test recipe number: 487/500
# Measuring perplexity on test recipe number: 488/500
# Measuring perplexity on test recipe number: 489/500
# Measuring perplexity on test recipe number: 490/500
# Measuring perplexity on test recipe number: 491/500
# Measuring perplexity on test recipe number: 492/500
# Measuring perplexity on test recipe number: 493/500
# Measuring perplexity on test recipe number: 494/500
# Measuring perplexity on test recipe number: 495/500
# Measuring perplexity on test recipe number: 496/500
# Measuring perplexity on test recipe number: 497/500
# Measuring perplexity on test recipe number: 498/500
# Measuring perplexity on test recipe number: 499/500
# Measuring perplexity on test recipe number: 500/500
# 28.54661483354698

# %%
for model_name in models:
    good_perp = calculate_perplexity(models[model_name], tokenizer, original_prompt, rest_of_instruction_step)
    print("Good Perplexity:", good_perp)

    bad_perp = calculate_perplexity(models[model_name], tokenizer, original_prompt, "preheat the oven to 1450 farheneight and put your baby in it")
    print("Bad Perplexity:", bad_perp)
# Out:
# Good Perplexity: 29.893831253051758
# Bad Perplexity: 537.0423583984375
# Good Perplexity: 36.46686553955078
# Bad Perplexity: 969.3562622070312
# Good Perplexity: 30.28963851928711
# Bad Perplexity: 600.8953857421875
# Good Perplexity: 35.73382568359375
# Bad Perplexity: 667.7882080078125
# Good Perplexity: 37.49321746826172
# Bad Perplexity: 573.7015991210938
