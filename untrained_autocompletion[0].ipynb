# %%
import torch
import pandas as pd
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load the pre-trained model and tokenizer
model_names = ['gpt2', './gpt2-finetuned-recipes-main', './gpt2-finetuned-recipes-bakery', './gpt2-finetuned-recipes-drinks', './gpt2-finetuned-recipes-meal']
models = {}

for model_name in model_names:
    tokenizer = GPT2Tokenizer.from_pretrained(model_name)
    letemcook = GPT2LMHeadModel.from_pretrained(model_name)
    # Set the model to evaluation mode
    letemcook.eval()
    models[model_name] = letemcook
# Out:
# 2024-11-21 22:11:48.747055: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-21 22:11:48.757885: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-21 22:11:48.831608: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-21 22:11:49.373986: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
test_datasets = []

test_dataset_names = ['Datasets/main_test_dataset.csv', 'Datasets/bakery_test_dataset.csv', 'Datasets/drinks_test_dataset.csv', 'Datasets/meal_test_dataset.csv']

for test_dataset_name in test_dataset_names:
    test_datasets.append(pd.read_csv(test_dataset_name))

# %%
# Function to generate text completion
def generate_completion(model, prompt, max_length=20):
    # Encode the input prompt
    inputs = tokenizer.encode(prompt, return_tensors='pt')
    # Generate output
    with torch.no_grad():
        outputs = model.generate(inputs, max_new_tokens=max_length, min_length = 3, temperature=0.5, do_sample=True)

    # Decode the generated output
    completion = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return completion

def make_prompt(title, ingredients, complete_instruction_steps, incomplete_instruction_steps):
    pre_prompt = "You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] "
    title_prompt = f"[RECIPE_TITLE] {title} " 
    ingredients_prompt = f"[INGREDIENTS_LIST] {ingredients} " 
    
    instructions_prompt = f"[STEPS] "
    for i, step in enumerate(complete_instruction_steps):
        instructions_prompt += f"{i + 1} - {step} "
    instructions_prompt += " " + f"{len(complete_instruction_steps) + 1} - {incomplete_instruction_steps}"
    
    prompt = pre_prompt + title_prompt + ingredients_prompt + instructions_prompt
    # prompt = pre_prompt + instructions_prompt
    return prompt

def autocomplete_recipe_step(model, title, ingredients, complete_instruction_steps, incomplete_instruction_steps, print_prompt = False, completiion_only = True):
    prompt = make_prompt(title, ingredients, complete_instruction_steps, incomplete_instruction_steps)
    if print_prompt: print(prompt)
    generated_string = generate_completion(model, prompt)
    if completiion_only:
        return generated_string[len(prompt):]
    return generated_string


def convert_string_to_list(input_string):
    clean_string = input_string.strip('[]')
    return [s.strip().strip('"') for s in clean_string.split('", "')] # assuming this is always a good split

def index_of_instruction_word(text, n):
    words = text.split()
    
    if n > len(words):
        return len(text) -1  
    
    position = 0
    for word in words[:n-1]:
        position += len(word) + 1 
    
    return position

def remove_next_step(step_number_to_remove, generated_autocompletion):
    next_step_token = f" {3} - "
    return generated_autocompletion.split(next_step_token, 1)[0]

from IPython.display import display, HTML
def display_prompt(text):
    display(HTML(f"<h1>Prompt</h1><p>{text}</p>"))

# %%
# Change nrows if desired
df = test_datasets[0]

# %%
def separate_recipe_components(recipe_index, n_complete_steps=2, n_words_before_autocomplete=3):

    test_rec = df.iloc[recipe_index, :]

    title = test_rec["title"]
    ingredients = test_rec["ingredients"]
    steps = convert_string_to_list(test_rec["directions"])
    
    

    if len(steps) <= n_complete_steps: return title, ingredients, steps[0:len(steps)-1], steps[len(steps)-1], steps[len(steps)-1]
    
    complete_steps = steps[:n_complete_steps - 1]

    true_step = steps[n_complete_steps]
    n_characters_before_autocomplete = index_of_instruction_word(true_step, n_words_before_autocomplete) # Not used for now
    incomplete_instruction_step = true_step[0:n_characters_before_autocomplete]
    rest_of_instruction_step = true_step[n_characters_before_autocomplete:]
    
    return title, ingredients, complete_steps, incomplete_instruction_step, rest_of_instruction_step

# %%
n_steps = 2
n_words_before_autocomplete = 3


for model_name in models:
    title, ingredients, complete_steps, incomplete_instruction_step, rest_of_instruction_step = separate_recipe_components(1, n_complete_steps=n_steps, n_words_before_autocomplete=n_words_before_autocomplete)
    original_prompt = make_prompt(title, ingredients, complete_steps, incomplete_instruction_step)
    autocompleted_step = autocomplete_recipe_step(models[model_name], title, ingredients, complete_steps, incomplete_instruction_step)
    # not yet implemented
    autocompleted_step = remove_next_step(n_steps + 1, autocompleted_step)
    print(original_prompt)
    print("-" * 80)
    print(autocompleted_step)
    print("-" * 80)
    print(rest_of_instruction_step)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] [RECIPE_TITLE] German Rotkohl - Spiced Red Cabbage With Apples And Wine [INGREDIENTS_LIST] ["1/4 cup chopped pork fat or 1/4 cup chopped bacon", "1 large red onion, finely chopped", "2 inches fresh ginger, peeled and finely chopped", "1/2 cinnamon stick", "1 large red cabbage, tough outer leaves removed, quartered, cored, and finely shredded", "1 sprig fresh marjoram", "1/2 teaspoon garam masala", "1/2 cup red wine vinegar", "1/2 cup ruby port or 1/2 cup madeira wine", "1/2 cup brown sugar or 1/2 cup real maple syrup", "1 bay leaf (optional)", "1 whole clove (optional)", "1 firm apple, chopped (optional)"] [STEPS] 1 - Cook the pork fat or bacon in a large skillet or dutch oven over low heat, stirring occasionally until it has rendered its fat, about 20 minutes for the pork fat or 10 minutes for the bacon.  2 - Add the
# --------------------------------------------------------------------------------
# iced red wine vinegar, 1/2 cup of marjoram, 1/2 cup of
# --------------------------------------------------------------------------------
# cabbage, stirring and cooking over medium heat until some of the bits are slightly browned and caramelized, about 10 minutes (I do this in batches). Note: You can skip the browning step if you are in a hurry, but I find that it adds a particularly wonderful caramelized flavor to the finished dish. Now add the marjoram, garam masala, vinegar, and port or Madeira, and stir well. (Note: At this point add the optional bay leaf, whole clove, and chopped apple).
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] [RECIPE_TITLE] German Rotkohl - Spiced Red Cabbage With Apples And Wine [INGREDIENTS_LIST] ["1/4 cup chopped pork fat or 1/4 cup chopped bacon", "1 large red onion, finely chopped", "2 inches fresh ginger, peeled and finely chopped", "1/2 cinnamon stick", "1 large red cabbage, tough outer leaves removed, quartered, cored, and finely shredded", "1 sprig fresh marjoram", "1/2 teaspoon garam masala", "1/2 cup red wine vinegar", "1/2 cup ruby port or 1/2 cup madeira wine", "1/2 cup brown sugar or 1/2 cup real maple syrup", "1 bay leaf (optional)", "1 whole clove (optional)", "1 firm apple, chopped (optional)"] [STEPS] 1 - Cook the pork fat or bacon in a large skillet or dutch oven over low heat, stirring occasionally until it has rendered its fat, about 20 minutes for the pork fat or 10 minutes for the bacon.  2 - Add the
# --------------------------------------------------------------------------------
# iced water and cook, stirring occasionally, until smooth, about 10 minutes.
# --------------------------------------------------------------------------------
# cabbage, stirring and cooking over medium heat until some of the bits are slightly browned and caramelized, about 10 minutes (I do this in batches). Note: You can skip the browning step if you are in a hurry, but I find that it adds a particularly wonderful caramelized flavor to the finished dish. Now add the marjoram, garam masala, vinegar, and port or Madeira, and stir well. (Note: At this point add the optional bay leaf, whole clove, and chopped apple).
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] [RECIPE_TITLE] German Rotkohl - Spiced Red Cabbage With Apples And Wine [INGREDIENTS_LIST] ["1/4 cup chopped pork fat or 1/4 cup chopped bacon", "1 large red onion, finely chopped", "2 inches fresh ginger, peeled and finely chopped", "1/2 cinnamon stick", "1 large red cabbage, tough outer leaves removed, quartered, cored, and finely shredded", "1 sprig fresh marjoram", "1/2 teaspoon garam masala", "1/2 cup red wine vinegar", "1/2 cup ruby port or 1/2 cup madeira wine", "1/2 cup brown sugar or 1/2 cup real maple syrup", "1 bay leaf (optional)", "1 whole clove (optional)", "1 firm apple, chopped (optional)"] [STEPS] 1 - Cook the pork fat or bacon in a large skillet or dutch oven over low heat, stirring occasionally until it has rendered its fat, about 20 minutes for the pork fat or 10 minutes for the bacon.  2 - Add the
# --------------------------------------------------------------------------------
# iced red chili powder, salt, and pepper to the skillet and cook until the chili is thick and
# --------------------------------------------------------------------------------
# cabbage, stirring and cooking over medium heat until some of the bits are slightly browned and caramelized, about 10 minutes (I do this in batches). Note: You can skip the browning step if you are in a hurry, but I find that it adds a particularly wonderful caramelized flavor to the finished dish. Now add the marjoram, garam masala, vinegar, and port or Madeira, and stir well. (Note: At this point add the optional bay leaf, whole clove, and chopped apple).
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] [RECIPE_TITLE] German Rotkohl - Spiced Red Cabbage With Apples And Wine [INGREDIENTS_LIST] ["1/4 cup chopped pork fat or 1/4 cup chopped bacon", "1 large red onion, finely chopped", "2 inches fresh ginger, peeled and finely chopped", "1/2 cinnamon stick", "1 large red cabbage, tough outer leaves removed, quartered, cored, and finely shredded", "1 sprig fresh marjoram", "1/2 teaspoon garam masala", "1/2 cup red wine vinegar", "1/2 cup ruby port or 1/2 cup madeira wine", "1/2 cup brown sugar or 1/2 cup real maple syrup", "1 bay leaf (optional)", "1 whole clove (optional)", "1 firm apple, chopped (optional)"] [STEPS] 1 - Cook the pork fat or bacon in a large skillet or dutch oven over low heat, stirring occasionally until it has rendered its fat, about 20 minutes for the pork fat or 10 minutes for the bacon.  2 - Add the
# --------------------------------------------------------------------------------
# iced water and cook until the bacon is tender, about 5 minutes.
# --------------------------------------------------------------------------------
# cabbage, stirring and cooking over medium heat until some of the bits are slightly browned and caramelized, about 10 minutes (I do this in batches). Note: You can skip the browning step if you are in a hurry, but I find that it adds a particularly wonderful caramelized flavor to the finished dish. Now add the marjoram, garam masala, vinegar, and port or Madeira, and stir well. (Note: At this point add the optional bay leaf, whole clove, and chopped apple).
# You are a chef-bot autocompleting a small part of a recipe: [START_OF_RECIPE] [RECIPE_TITLE] German Rotkohl - Spiced Red Cabbage With Apples And Wine [INGREDIENTS_LIST] ["1/4 cup chopped pork fat or 1/4 cup chopped bacon", "1 large red onion, finely chopped", "2 inches fresh ginger, peeled and finely chopped", "1/2 cinnamon stick", "1 large red cabbage, tough outer leaves removed, quartered, cored, and finely shredded", "1 sprig fresh marjoram", "1/2 teaspoon garam masala", "1/2 cup red wine vinegar", "1/2 cup ruby port or 1/2 cup madeira wine", "1/2 cup brown sugar or 1/2 cup real maple syrup", "1 bay leaf (optional)", "1 whole clove (optional)", "1 firm apple, chopped (optional)"] [STEPS] 1 - Cook the pork fat or bacon in a large skillet or dutch oven over low heat, stirring occasionally until it has rendered its fat, about 20 minutes for the pork fat or 10 minutes for the bacon.  2 - Add the
# --------------------------------------------------------------------------------
# iced ginger and saute for about 10 minutes or until the ginger is soft, about 5 minutes.",
# --------------------------------------------------------------------------------
# cabbage, stirring and cooking over medium heat until some of the bits are slightly browned and caramelized, about 10 minutes (I do this in batches). Note: You can skip the browning step if you are in a hurry, but I find that it adds a particularly wonderful caramelized flavor to the finished dish. Now add the marjoram, garam masala, vinegar, and port or Madeira, and stir well. (Note: At this point add the optional bay leaf, whole clove, and chopped apple).

# %%
model_results = {}

for model_name in models:
    
    recipes = df.index.tolist()
    results = []

    for recipe_index in recipes:

        # Mess around with n_complete_steps and n_words_before_autcomplete    
        title, ingredients, complete_steps, incomplete_instruction_step, true_step = separate_recipe_components(recipe_index, n_complete_steps=2, n_words_before_autocomplete=4)
        autocompleted_step = autocomplete_recipe_step(models[model_name], title, ingredients, complete_steps, incomplete_instruction_step)
        results.append((incomplete_instruction_step, true_step, autocompleted_step))


    model_results[model_name] = results
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# ...
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.

# %%
for model_name in model_results:
    results = model_results[model_name]
    
    for result in results:
        print("-" * 80)
        print(f"Autocompleting the instruction step starting with: {result[0]}")
        print(f"TRUE STEP: {result[1]}")
        print(f"Autocompleted STEP: {result[2]}")
        #display_prompt(result[2])
# Out:
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cook noodles according
# TRUE STEP: to package directions.
# Autocompleted STEP:  to package directions.  3 - Add all ingredients, bring to a boil, then reduce
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add the cabbage,
# TRUE STEP: stirring and cooking over medium heat until some of the bits are slightly browned and caramelized, about 10 minutes (I do this in batches). Note: You can skip the browning step if you are in a hurry, but I find that it adds a particularly wonderful caramelized flavor to the finished dish. Now add the marjoram, garam masala, vinegar, and port or Madeira, and stir well. (Note: At this point add the optional bay leaf, whole clove, and chopped apple).
# Autocompleted STEP:  and ginger to the pan and bring to a boil.  3 - Reduce the heat to low
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Peel the cucumbers. Cut each in half lengthwise. Scoop out the seeds and thinly slice the cucumbers. Sprinkle with salt and put into a large colander to drain for 30 minutes. Meanwhile in a large bowl, combine the yogurt, vinegar and herbs and season with salt and pepper to taste.
# TRUE STEP: Peel the cucumbers. Cut each in half lengthwise. Scoop out the seeds and thinly slice the cucumbers. Sprinkle with salt and put into a large colander to drain for 30 minutes. Meanwhile in a large bowl, combine the yogurt, vinegar and herbs and season with salt and pepper to taste.
# Autocompleted STEP:  Whisk until smooth. Remove from the colander and set aside. 2 - Combine the parsley
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix curry powder, 1/4 teaspoon salt and pepper. Pat chicken breasts dry. Sprinkle with and rub in spice mix. Combine 1/4 teaspoon salt with next 5 ingredients is large skillet. Arrange chicken over mix. Bring to boil, cover, reduce heat and simmer 20 minutes. Remove from heat. Let stand, covered, 5 minutes. Remove to serving plate; sprinkle with parsley.
# TRUE STEP: Mix curry powder, 1/4 teaspoon salt and pepper. Pat chicken breasts dry. Sprinkle with and rub in spice mix. Combine 1/4 teaspoon salt with next 5 ingredients is large skillet. Arrange chicken over mix. Bring to boil, cover, reduce heat and simmer 20 minutes. Remove from heat. Let stand, covered, 5 minutes. Remove to serving plate; sprinkle with parsley.
# Autocompleted STEP:
#
# RAW Paste Data
#
# [START_OF_RECIPE] [RECIP
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cut into bite
# TRUE STEP: size pieces.
# Autocompleted STEP:  3 - Add cheese.  4 - Add chicken.  5 - Add chicken, add salt.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake at 375\u00b0
# TRUE STEP: for 45 minutes.
# Autocompleted STEP:  or until golden brown. 3 - Add the bacon and onions and cook for 15 minutes or until
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Sprinkle a little
# TRUE STEP: Splenda in middle of foil.
# Autocompleted STEP: iced apple cider over the top of the apple.  3 - Add the iced apple to the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Spread on baking
# TRUE STEP: sheet and sprinkle with salt
# Autocompleted STEP:  3 - Bake for 10 minutes  Instructions Make the following steps: 1. In a large bowl,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add the honey
# TRUE STEP: and olive oil to the strained vinegars and whisk.
# Autocompleted STEP:  and 1 tablespoon of honey to the water. Stir to combine. Add the vinegar. Stir to
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: After it is
# TRUE STEP: mixed, thoroughly chill by placing it in the fridge for an hour or two.
# Autocompleted STEP:  cool, add the sugar and vanilla extract.  3 - Pour into a small saucepan and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Find lengthwise seam in dough. Beginning at seam, gently unroll dough into a rectangle on a lightly floured surface. Roll dough into a 15 x 13-inch rectangle on a lightly floured surface. Brush dough evenly with 1 tablespoon oil. Combine cheese and the next 4 ingredients (through salt), stirring well; sprinkle half of mixture evenly over dough, pressing gently to adhere. Turn dough over. Brush dough with remaining 1 tablespoon oil; sprinkle with remaining cheese mixture. Cut the dough lengthwise into 48 thin strips (about 1/4-inch-thick) using a pizza cutter. Place strips on baking sheets coated with cooking spray. Bake in batches at 425\u00b0 for 4 minutes or until golden and crisp.
# TRUE STEP: Find lengthwise seam in dough. Beginning at seam, gently unroll dough into a rectangle on a lightly floured surface. Roll dough into a 15 x 13-inch rectangle on a lightly floured surface. Brush dough evenly with 1 tablespoon oil. Combine cheese and the next 4 ingredients (through salt), stirring well; sprinkle half of mixture evenly over dough, pressing gently to adhere. Turn dough over. Brush dough with remaining 1 tablespoon oil; sprinkle with remaining cheese mixture. Cut the dough lengthwise into 48 thin strips (about 1/4-inch-thick) using a pizza cutter. Place strips on baking sheets coated with cooking spray. Bake in batches at 425\u00b0 for 4 minutes or until golden and crisp.
# Autocompleted STEP:  Remove from oven and allow to cool. [START_OF_RECIPE] [REC
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: *Adobo sauce is the thick liquid that comes with canned chipotle peppers. Look for them in the Mexican sections of supermarkets or at Mexican grocery stores.
# TRUE STEP: *Adobo sauce is the thick liquid that comes with canned chipotle peppers. Look for them in the Mexican sections of supermarkets or at Mexican grocery stores.
# Autocompleted STEP:  They are not as spicy as the chips. 3 - Add the chipotle sauce to the saucepan
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake for 45
# TRUE STEP: minutes at 350\u00b0.
# Autocompleted STEP:  minutes.  3 - Remove from oven.  4 - Remove from oven and let cool
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Warm fudge sauce
# TRUE STEP: slightly and drizzle over ice cream layer.
# Autocompleted STEP:  3 - Add cookies to pan. 4 - Pour into pan and bake for 30 minutes. 5 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Serve with butter
# TRUE STEP: crackers.
# Autocompleted STEP:  3 - Place cheese on top of cheese.  4 - Roll up to a length of 8 inches
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a small
# TRUE STEP: pan, put butter and brown sugar.
# Autocompleted STEP:  bowl, heat butter until slightly browned but don't over heat.  3 - Add the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add onion, if
# TRUE STEP: desired.
# Autocompleted STEP:  you don't have it.  3 - Add garlic, if  you don't have
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Heat oil in saute pan and cook sturgeon until browned on both sides and done, 5 to 8 minutes.
# TRUE STEP: Heat oil in saute pan and cook sturgeon until browned on both sides and done, 5 to 8 minutes.
# Autocompleted STEP:  3 - Add the pears and cook until golden brown, 5 to 6 minutes. 4 - Remove
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Combine the vinegar
# TRUE STEP: with 3 tablespoons water. Add Italian dressing mix and shake well. Add oil and rest of water and shake well. Measure out a quarter cup, pour over salad and toss gently.
# Autocompleted STEP:  and water in a large bowl.  3 - Add the garlic, onion, and garlic cl
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Separate the eggs,
# TRUE STEP: you will be left with two spare yolks, which can be made into something at a later date. My fool proof method to separating eggs is to have three clean bowls, two small and one large. Crack the egg into your hand as below and allow the whites to drop through your fingers into one of the small bowls. Keep your fingers reasonably close together as you don't want the yolk to break or drop through. Gently place the yolk into the other small bowl. Transfer the whites into the large bowl. Repeat by cracking another egg into your hand over the now empty small bowl allowing the white to fall through then adding the unbroken yolk to the other yolk.
# Autocompleted STEP:  and the limes from the ramekins and mix well.  Use a spoon to
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add in the
# TRUE STEP: Large eggs and mix thoroughly.
# Autocompleted STEP: ices and 1 tbsp. dry crushed red peppers. 3 - Add in the rest of ingredients and mix
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Preheat an outdoor
# TRUE STEP: grill for medium-high heat and lightly oil grate. Thread chicken onto skewers.
# Autocompleted STEP: iced coffee grinder to 350 degrees F.  3 - Add the chicken, garlic, ginger,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cook ground beef in large pan. Add to the cooked meat bean sprouts, green onions, cabbage, garlic powder and soy sauce. Cook until tender. Cool and drain.
# TRUE STEP: Cook ground beef in large pan. Add to the cooked meat bean sprouts, green onions, cabbage, garlic powder and soy sauce. Cook until tender. Cool and drain.
# Autocompleted STEP:  2 - Add to the pan a small amount of oil, then add to the pan a large amount
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place apples in a 13x9-in. baking dish; add water. Cover and bake at 350\u00b0 for 30-40 minutes or until tender. Remove from the oven and keep warm. In a small saucepan, combine sugar, flour and nutmeg. Stir in cream. Cook and stir over medium heat until thickened and bubbly. Cook 2 minutes longer. Remove from the heat. Serve warm over apples.
# TRUE STEP: Place apples in a 13x9-in. baking dish; add water. Cover and bake at 350\u00b0 for 30-40 minutes or until tender. Remove from the oven and keep warm. In a small saucepan, combine sugar, flour and nutmeg. Stir in cream. Cook and stir over medium heat until thickened and bubbly. Cook 2 minutes longer. Remove from the heat. Serve warm over apples.
# Autocompleted STEP:
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Keep in sealed container.
# TRUE STEP: Keep in sealed container.
# Autocompleted STEP:   3 - Put in the refrigerator.  4 - Open the lid and allow to cool.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Use lettuce leaves
# TRUE STEP: as a bed for this salad and sprinkle with grated nuts.
# Autocompleted STEP:  3 - Use the salad dressing to mix the dressing ingredients.  4 - Add the salad dressing to
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a medium
# TRUE STEP: bowl, whisk together the rice milk and the lemon juice and let stand for a minute or two. Whisk in the eggs and oil or melted coconut butter.
# Autocompleted STEP:  pan, combine flour, salt, baking powder, baking soda, baking soda, baking soda mixture
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Dredge 4 shrimp
# TRUE STEP: in the flour mixture, then dip them in the egg mixture and coat them in the coconut mixture. Dip them again in the egg mixture and coat one more time in the coconut mixture.
# Autocompleted STEP:  (I used a large, round shrimp) in 1/4 cup water.  3 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Core, seed and
# TRUE STEP: coarsely chop peppers.
# Autocompleted STEP:  (or more if you're using a food processor) 1 - I use a food processor.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a large
# TRUE STEP: pot heat olive oil over medium-high heat; add in garlic and saute for 2 minutes.
# Autocompleted STEP: iced water bowl, whisk together the flour, salt, baking soda, baking powder, nutmeg,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake at 350\u00b0 for 15 minutes, then turn down to 325\u00b0 for 45 to 60 minutes.
# TRUE STEP: Bake at 350\u00b0 for 15 minutes, then turn down to 325\u00b0 for 45 to 60 minutes.
# Autocompleted STEP:   3 - Pour into pie shells and bake for 10 minutes.  4 - Remove from oven and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake at 350\u00b0
# TRUE STEP: for 40 or 45 minutes.
# Autocompleted STEP: ....................................................... 1 - Line greased 9-inch pie pan with slices of cheese.  3
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place two banana halves in a serving dish; add 3 scoops vanilla ice cream between banana halves. Top with half each of Hot Fudge Sauce, blackberries, raspberries, and chopped salted peanuts. Repeat procedure with remaining ingredients.
# TRUE STEP: Place two banana halves in a serving dish; add 3 scoops vanilla ice cream between banana halves. Top with half each of Hot Fudge Sauce, blackberries, raspberries, and chopped salted peanuts. Repeat procedure with remaining ingredients.
# Autocompleted STEP:  2 - Add 1/3 cup chopped peanuts to top of the hot-fudge sauce. 3
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix and cook at 375\u00b0.
# TRUE STEP: Mix and cook at 375\u00b0.
# Autocompleted STEP:  2 - Add the flour and salt to a bowl. 3 - Add the flour and salt to a
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Take butter knife,
# TRUE STEP: go up and down pan to swirl together.
# Autocompleted STEP:  and cut into slices.  Use a fork to cut slices.  Cut into 2
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cu
# TRUE STEP: t
# Autocompleted STEP: pping  3 - Spread  4 - Cook  5 - Serve  6 - Garnish  7
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Leaving a 4-inch
# TRUE STEP: hole in center, arrange 8 balls, seam side down and sides almost touching, into ring on cookie sheet. Arrange remaining 12 balls, sides almost touching, around outer edge of first ring. Brush rings with beaten egg. Sprinkle with Parmesan cheese and Italian seasoning.
# Autocompleted STEP:  hole in the middle of the biscuit, press the biscuit into the middle of the bisc
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix enough remaining
# TRUE STEP: flour to make dough smooth, scraping sides well.
# Autocompleted STEP:  - yeast to make a paste. 3 - Add to a pan. 4 - Pour into a
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add orange juice,
# TRUE STEP: lemonade, sloe gin and 2 cups cold water.
# Autocompleted STEP: iced water, and lemon juice.  3 - Add ice.  4 - Add chilled orange juice
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In double boiler,
# TRUE STEP: melt marshmallows and cream cheese.
# Autocompleted STEP:  mix the jello mixture with the lemon juice.  3 - Add 1 cup hot water and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add corn and
# TRUE STEP: soup.
# Autocompleted STEP:  set aside. 3 - Add cream of chicken soup. 4 - Add milk and stir. 5
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Simmer for 5-
# TRUE STEP: 10 minutes.
# Autocompleted STEP:  minutes, or until the garlic is softened.  3 - Add the tomatoes, garlic,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place a piece
# TRUE STEP: of phyllo on a nonstick cookie sheet and brush with some of the melted butter. Repeat 3 more times, placing each of phyllo over the last buttered sheet to make 4 layers. Cut layered phyllo into 16 rectangles (4 x 4).
# Autocompleted STEP:  of chicken skin on a baking sheet.  Place in the oven for 5 minutes or until
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Grill, split-side down,
# TRUE STEP: until golden, about 30 to 45 seconds.
# Autocompleted STEP:  about 3 minutes.  Spread the ingredients evenly over the top of the pan, and cook
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place ripe bananas
# TRUE STEP: in a large mixing bowl. Using a potato masher or a large fork, mash the bananas well. You want them to be relatively smooth, but a few lumps are fine. Mix the melted coconut oil (or melted butter) into the bananas. Add the brown sugar, egg, vanilla, cinnamon, nutmeg and salt, and mix well. Sprinkle the baking soda over the batter and then mix it in. Add the flour last, making sure everything is well combined.
# Autocompleted STEP:  in a medium bowl.  Spread out  the bananas on a thin sheet of parchment
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Then add well
# TRUE STEP: beaten eggs, onion, cheese and cracker crumbs.
# Autocompleted STEP:  (or skip this step and take a little time).  3 - Next, add in the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Put all ingredients
# TRUE STEP: except for the flour into a plastic bag.
# Autocompleted STEP:  into a large bowl.  3 - Add the chicken to the chicken tenders.  4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add turkey, 2
# TRUE STEP: cups of the barbecue sauce (or 1/2 cup for trial recipe), the tomato paste, eggs and seasonings; mix well.
# Autocompleted STEP:  parsley leaves, 1 Tbsp. dried oregano leaves, 1 tsp. garlic
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Broil the peaches
# TRUE STEP: for about 15 minutes, flipping them halfway through, until caramelized and juicy.
# Autocompleted STEP:  and set aside.  3 - In a large bowl, combine the flour, sugar, baking
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Turn the heat
# TRUE STEP: off and whisk the shallots into the bacon grease.
# Autocompleted STEP:  on to medium high heat.  3 - Add the egg, garlic, and vinegar and cook
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour over chicken
# TRUE STEP: and broccoli evenly.
# Autocompleted STEP:  and broccoli.  3 - Add remaining ingredients.  4 - Add remaining ingredients.  5
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Use tart pans
# TRUE STEP: with removable bottoms OR large ramekins (4 1/4\" in diameter).
# Autocompleted STEP:  (I used a large pan)  (I used a small pan) 3 - Put
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Spoon in shortening
# TRUE STEP: or butter and the sugar mixture.
# Autocompleted STEP:  (or butter)  and mix well.  3 - Pour in the flour,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Then continue with
# TRUE STEP: recipe.
# Autocompleted STEP:  cooking until the ribbons are cooked through.  3 - Add the remaining ingredients (reci
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Remove and keep
# TRUE STEP: warm.
# Autocompleted STEP:  in the refrigerator for about 10 minutes, then stir in the bacon and onion.  3 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bring to boil;
# TRUE STEP: cover.
# Autocompleted STEP:  add onions, celery, garlic, and salt. 3 - Add garlic. 4 - Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir in beef
# TRUE STEP: broth, tomato soup and water. Bring to a boil over medium-high heat, then turn heat down to a simmer (medium to medium-low). Add the vegetables and continue to simmer until vegetables are hot,; about 6-8 minutes. Stir in cooked pasta.
# Autocompleted STEP:  and cook for 1 minute or until cooked through. Remove from heat.  3 - Add broth
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Push together and
# TRUE STEP: chill in the refrigerator for several hours or overnight.
# Autocompleted STEP:  punch together.  Add flour, butter and nut mixture into the butter mixture.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix together all
# TRUE STEP: of the meats.
# Autocompleted STEP:  the ingredients in the pan.  3 - Add the vegetables, potatoes, onions, celery
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Store in glass container or baggies.
# TRUE STEP: Store in glass container or baggies.
# Autocompleted STEP:  3 - Pour in salted peanuts and yogurt. 4 - Add honey graham crackers to mix
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cover. Refrigerate at
# TRUE STEP: least 1 hour.
# Autocompleted STEP:  20 minutes. 3 - Remove from refrigerator and let cool for 3 hours. 4 - In a
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Reduce heat to
# TRUE STEP: low and cook until butter is light brown, stirring often, about 5 minutes.
# Autocompleted STEP:  low and simmer for 15 minutes or until the butter is melted. 3 - Add the butter and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake until golden,
# TRUE STEP: about 12 minutes.
# Autocompleted STEP:  (45 minutes) and set aside. [START_OF_RECIPE] [
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Repeat until all is used.
# TRUE STEP: Repeat until all is used.
# Autocompleted STEP:  3 - Add to the mix. 4 - Add to the mix. 5 - Add to the mix
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Form burgers into
# TRUE STEP: 1/2 inch thick patties. Lightly oil grate. Place burgers on grill. Cook for approximately 6 minutes, turning once.
# Autocompleted STEP:  small cubes using a large spoon. Remove from the heat and let cool. 3 - In a
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Refrigerate and serve
# TRUE STEP: .
# Autocompleted STEP: . 3 - Add the pasta shells to a large bowl and toss to coat. 4 - Pour the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour into glasses
# TRUE STEP: .
# Autocompleted STEP:  and let sit for 10 minutes.  3 - Remove from fridge and let cool.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add the garlic,
# TRUE STEP: tomatoes, sugar, and cinnamon.
# Autocompleted STEP:  and cook for 5 minutes.  3 - Add the tomatoes and cook for 5 minutes.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Heat a non-stick
# TRUE STEP: frying pan over high heat. Add the oil, ginger, lemongrass chile and optional jalapeno and saute for 1 minute.
# Autocompleted STEP: iced tea towel over medium heat. Add noodles and stir well.  3 - Add water and stir
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: 3. Add tomato
# TRUE STEP: sauce, chickpeas, and 1 1/2 cups water. Bring to a boil; reduce to a simmer, and cook, stirring occasionally, until thickened, 8 to 10 minutes. Stir in lime juice; season with salt and pepper. Serve stew with rice and yogurt, garnished with lime wedges and a pinch of curry.
# Autocompleted STEP:  (or 1 tablespoon of curry powder), and mix well. 4 - 5. Serve.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Heat lowfat milk,
# TRUE STEP: water and 1/4 c. butter to 105-115
# Autocompleted STEP:  1/2 c. milk and  1/2 c. water in a large sauce
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Saute 2 to
# TRUE STEP: 3 more minutes.
# Autocompleted STEP:  2 cups of chicken stock in a large skillet over medium heat.  3 - Add 1 to
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Lay bacon on
# TRUE STEP: steaks.
# Autocompleted STEP:  bread sheet.  3 - Place bacon on  bread sheet.  4 - Put bacon
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: or bread done
# TRUE STEP: in a blender, egg, ketchup to taste, salt and pepper.
# Autocompleted STEP:  3 - Place in fridge.  4 - Put meat into fridge.
#
# RAW Paste Data
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a small bowl, beat the cream cheese, sugar and extract until smooth. Spoon into shells. Top with pie filling. Refrigerate until serving.
# TRUE STEP: In a small bowl, beat the cream cheese, sugar and extract until smooth. Spoon into shells. Top with pie filling. Refrigerate until serving.
# Autocompleted STEP:  Instructions: 1. In a small bowl, beat the cream cheese, sugar and extract until smooth.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Heat until sugar
# TRUE STEP: is melted, then pour over pickles in jar.
# Autocompleted STEP: ------------ [STEPS] 2 - Heat 2 Tbsp. of the vinegar ------------ [STEPS
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Combine dry ingredients
# TRUE STEP: in a large bowl.
# Autocompleted STEP:  in a large bowl and whisk until smooth.  Add in the flour and mix well.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: I usually put
# TRUE STEP: some of the mixture (so i do not dilute the mixture with ice) in the bottom of a nice mold and drop cherries, kiwis whatever you like to make a nice decoration and then put that in the freezer. When guests arrive I take it out and drop it in my punch bowl, looks really good.
# Autocompleted STEP:  one liter of cream soda in the fridge, and then I mix it up.  3 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Dip a lime
# TRUE STEP: half in the chile salt and dab the vegetables with it; squeeze the juice over the vegetables.
# Autocompleted STEP:  in water and add the onions.  3 - Add the carrots and onions.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Let soak for
# TRUE STEP: 2 to 3 hours.
# Autocompleted STEP:  3 minutes.  3 - Take off the rice and rinse.  4 - Take the rice
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cook broccoli until just tender. Put through chopper of food processor. Mix chopped broccoli, soup and milk. Heat and serve.
# TRUE STEP: Cook broccoli until just tender. Put through chopper of food processor. Mix chopped broccoli, soup and milk. Heat and serve.
# Autocompleted STEP:  2 - Cook broccoli until just tender. Put through chopper of food processor. Mix chopped broccoli,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Make doug
# TRUE STEP: h
# Autocompleted STEP:  flour  3 - Mix flour  4 - Mix flour with a fork  5 - Mix flour with
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: or until potatoes
# TRUE STEP: are lightly browned, stirring occasionally.
# Autocompleted STEP:  are tender and crispy.  3 - or until potatoes are tender and crispy.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix sour cream
# TRUE STEP: and sugar.
# Autocompleted STEP:  with water.  3 - Add the pineapple juice, mandarin oranges, and sugar.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: 1
# TRUE STEP: .
# Autocompleted STEP: st Step: [SINGLE_STEP] 3 - Preparation Time: 25 min Soaking
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Season with fresh
# TRUE STEP: ground black pepper.
# Autocompleted STEP: iced tea, 1/2 cup of olive oil, 1/4 cup of garlic powder.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake at 350\u00b0
# TRUE STEP: for 50 minutes.
# Autocompleted STEP:  for 30 minutes. Remove from oven and let cool. 3 - Cool on wire rack for 20
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add in dry
# TRUE STEP: ingredients alternately with buttermilk to the creamed mix.
# Autocompleted STEP: iced cream.  3 - Add in dry sugar.  4 - Add in dry iced cream
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Stir kale and rice into the boiling broth mixture; return the broth to a boil, place a cover on the pot, reduce heat to low, and continue cooking at a simmer until the rice is cooked through and tender, 20 to 25 minutes.
# TRUE STEP: Stir kale and rice into the boiling broth mixture; return the broth to a boil, place a cover on the pot, reduce heat to low, and continue cooking at a simmer until the rice is cooked through and tender, 20 to 25 minutes.
# Autocompleted STEP:  [PRINT] [PRINT_SIZE] [PRINT_NAME] [PRINT_
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Turn the dough
# TRUE STEP: out on to a lightly floured work surface and knead for 30 seconds. Cover with a clean towel and let rest for 10 minutes. Punch the dough down and divide into 12 equal-sized pieces. Shape each piece into a smooth ball and place evenly into a lightly greased 9- or 10-inch pie dish. Cover with towel and let rise in a warm, draft-free spot for 20 to 30 minutes.
# Autocompleted STEP:  and knead for about 8 to 10 minutes, turning occasionally. Add a second dough hook and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a large
# TRUE STEP: bowl, toss the chicken with the bread crumb mixture.
# Autocompleted STEP: iced iced iced iced iced iced pan, combine 2 tablespoons of the oil and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Saute garlic and
# TRUE STEP: olive oil in a pan for about 30 seconds.
# Autocompleted STEP:  spice in a large saucepan over medium heat.  3 - Add spinach, garlic
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a large
# TRUE STEP: bowl, mix breads and vegetables.
# Autocompleted STEP:  pan, melt butter and stir in 1/2 cup of the flour.  3 - Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour milk onto
# TRUE STEP: dry ingredients.
# Autocompleted STEP:  a small baking dish.  3 - Assemble the batter.  4 - Bake for 20
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Serve as a
# TRUE STEP: dip for meat balls or egg rolls.
# Autocompleted STEP: iced tea or iced coffee. [START_OF_RECIPE] [RECIP
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Bake at 350\u00b0 for 30 minutes or until bubbly.
# TRUE STEP: Bake at 350\u00b0 for 30 minutes or until bubbly.
# Autocompleted STEP:  Remove from oven and cool completely.  3 - Top with remaining ingredients, and serve.
#
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Grill over hot
# TRUE STEP: coals, until done as desired, turning often to brown evenly.
# Autocompleted STEP: iced coffee.  3 - Add chicken, carrots, and celery to the stir fry pan.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: To smoke the
# TRUE STEP: salad, heat one piece charcoal over open flame until gray and reddish in color. Place a small square of aluminum foil in the eggplant salad (make room in the center for the foil). Place the hot charcoal on the piece of foil in the bowl. Add the margarine on top of the charcoal and cover salad bowl immediately. Allow to smoke for 10 minutes; remove charcoal.
# Autocompleted STEP: iced tea, add the ground ginger and milk. Mix well. 3 - To serve, add the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour into baked
# TRUE STEP: pie shell.
# Autocompleted STEP:  pie shell.  3 - Remove from oven and put into a large bowl and let cool
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Transfer onion mixture to a bowl. Sprinkle with rosemary, salt, pepper and paprika. Serve warm.
# TRUE STEP: Transfer onion mixture to a bowl. Sprinkle with rosemary, salt, pepper and paprika. Serve warm.
# Autocompleted STEP:
#
# Recipe:
#
# Stir the onion mixture into the skillet. Add the leek and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add canned tomatoes;
# TRUE STEP: mash and let cook down some. Add ground beef and let cook about 2 hours, then add kidney beans. Cook about 20 minutes.
# Autocompleted STEP:  3 - Add cooked beans.  4 - Add chili powder.  5 - Add chili powder.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: dish
# TRUE STEP: .
# Autocompleted STEP: , refrigerate until ready to use.  3 - Place all ingredients in a large bowl, and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: When done, drain
# TRUE STEP: off grease.
# Autocompleted STEP:  3 - Remove from skillet and add seasoning to taste. 4 - Cook celery and onion in small
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix, place in 9 x 13-inch pan and freeze.
# TRUE STEP: Mix, place in 9 x 13-inch pan and freeze.
# Autocompleted STEP:  2 - Add to freezer. 3 - Pour into pan and freeze. 4 - Pour into pan and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add remaining ingredients
# TRUE STEP: .
# Autocompleted STEP:  to a large bowl.  3 - Add butter, sugar and vanilla.  4 - Add peanut
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Set aside
# TRUE STEP: .
# Autocompleted STEP: . 3 - Put the shrimp in a large bowl and add the garlic, shallots, and thy
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Let cool
# TRUE STEP: .
# Autocompleted STEP:  completely. 3 - Remove cake from pan. 4 - Pour batter into pan and let cool completely.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place chicken breasts
# TRUE STEP: in pan.
# Autocompleted STEP:  on the cutting board and place them on a cutting board.  3 - Place chicken breasts
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Drain fettuccine; place
# TRUE STEP: in a large bowl. Add cream sauce and garlic; toss to coat. Sprinkle with Parmesan cheese.
# Autocompleted STEP:  in a blender along with 1/2 cup of heavy whipping cream. Blend until smooth. Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Sprinkle with seasoning
# TRUE STEP: salt and parsley.
# Autocompleted STEP:  (optional) 3 - Put potatoes in a bowl and cover with foil.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Slice 1 head cauliflower into florets and halve; spread in a single layer on a baking sheet. Drizzle with 3 tablespoons olive oil. Sprinkle with 1/4 cup grated parmesan, 1 1/2 teaspoons chopped mixed thyme and rosemary, 1 teaspoon kosher salt and a few grinds of pepper. Roast at 425 degrees F, 30 minutes; flip and roast 15 more minutes.
# TRUE STEP: Slice 1 head cauliflower into florets and halve; spread in a single layer on a baking sheet. Drizzle with 3 tablespoons olive oil. Sprinkle with 1/4 cup grated parmesan, 1 1/2 teaspoons chopped mixed thyme and rosemary, 1 teaspoon kosher salt and a few grinds of pepper. Roast at 425 degrees F, 30 minutes; flip and roast 15 more minutes.
# Autocompleted STEP:  [SIDE_INVALIDITY] [SIDE_INVALIDITY] [S
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Boil 5 minutes
# TRUE STEP: .
# Autocompleted STEP: .  3 - Add 1 tablespoon butter, 1 teaspoon cocoa and 1/2 teaspoon vanilla.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cover and chill
# TRUE STEP: in the refrigerator for 1 hour.
# Autocompleted STEP:  3 - Place the ingredients in a large bowl.  4 - Add the salt and pepper.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix in dip
# TRUE STEP: .
# Autocompleted STEP: .  3 - Add in the cheese and stir.  4 - Add in the meat.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a small
# TRUE STEP: bowl, mix the brown sugar and 2 tablespoons of the melted butter until well combined.
# Autocompleted STEP:  bowl, mix the flour, baking powder, salt, and baking soda in a small bowl.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add onion; cook
# TRUE STEP: for 1 to 2 minutes.
# Autocompleted STEP:  for 1 minute.  Add garlic and cook for 1 minute. 3 - Add beef tender
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add remaining ingredients and marinate 30 minutes or more.
# TRUE STEP: Add remaining ingredients and marinate 30 minutes or more.
# Autocompleted STEP:  3 - Add remaining ingredients and marinate 30 minutes or more. 4 - Add remaining ingredients and mar
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour about 1/2
# TRUE STEP: teaspoon of olive oil into the centre of each garlic head.
# Autocompleted STEP:  of the olive oil into the garlic and cook until the garlic is almost done. 3 - Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Chop cilantro
# TRUE STEP: .
# Autocompleted STEP: . 3 - Add salt and pepper to the mozzarella balls. 4 - Add salt and pepper
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Refrigerate and serve.
# TRUE STEP: Refrigerate and serve.
# Autocompleted STEP:   Recipe Notes: - You can leave it out of the fridge for a few days to make sure
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Remove from oven
# TRUE STEP: and cool.
# Autocompleted STEP:  Cover with foil and refrigerate for at least 10 minutes.  3 - In a large saucepan
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Beat with beater until stiff.
# TRUE STEP: Beat with beater until stiff.
# Autocompleted STEP:  2 - Add flour and whisk until just combined. 3 - Add egg whites and whisk until combined.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Combine all ingredients
# TRUE STEP: in a large bowl.
# Autocompleted STEP: -------------- [START_OF_RECIPE] [RECIPE_TITLE] Asian
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In 10-inch skillet or 3-quart saucepan with wire whisk, mix milk and cornstarch until blended; heat to boiling over high heat, stirring frequently. Reduce heat to medium and cook until sauce thickens slightly, about 1 minute, stirring constantly.
# TRUE STEP: In 10-inch skillet or 3-quart saucepan with wire whisk, mix milk and cornstarch until blended; heat to boiling over high heat, stirring frequently. Reduce heat to medium and cook until sauce thickens slightly, about 1 minute, stirring constantly.
# Autocompleted STEP:  Remove from heat and stir in remaining butter. Stir in fresh thyme, parsley, and herbs
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: and bake in
# TRUE STEP: a 13 x 9-inch greased pan at 375\u00b0 for 50 to 60 minutes or until brown.
# Autocompleted STEP:  a preheated oven for about 8 hours. 2 - Cut the bacon into 6 pieces and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: When cold add
# TRUE STEP: the minced parsley and the lemon juice.
# Autocompleted STEP:  1 cup of the turkey sauce/juices.  3 - Add the eggs and flour and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cook, covered, at
# TRUE STEP: 350 for 30 minutes; uncover and stir well.
# Autocompleted STEP:  30°C for 20 minutes.  3 - Add the onions, mushrooms, and mushrooms to
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Boil potatoes 10
# TRUE STEP: minutes and drain.
# Autocompleted STEP: -------------------------- 3 - Boil potatoes 10 -------------------------- 4 - Boil potatoes 10 --------------------------
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place crust in
# TRUE STEP: bottom of pie plate. Fill with apple mix and dab with the 4 tablespoons vegan margarine. Cover with top crust. If you like, brush with 1 egg mixed with 1 tablespoon of water.
# Autocompleted STEP:  a saucepan and heat over medium-high heat.  3 - Add chopped strawberries, apple
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Serve
# TRUE STEP: .
# Autocompleted STEP:  with a side of rice and a side of the avocado.
#
# Recipe for Raspberry Spinach Salad
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Sift the next
# TRUE STEP: 5 ingredients.
# Autocompleted STEP:  ingredients into a mixing bowl.  3 - Rub the ingredients together in a food processor until smooth.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Serves 6
# TRUE STEP: .
# ...
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix soup and
# TRUE STEP: wine (or water) together and pour over chicken.
# Autocompleted STEP: iced water together.  3 - Add sauce, mix well.  4 - Cover and bake at
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour cherry juice into a 16 ounce glass; pour in beer. Drink!
# TRUE STEP: Pour cherry juice into a 16 ounce glass; pour in beer. Drink!
# Autocompleted STEP:  You can add more or less at a time, depending on your preference. (Optional: You can
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cook
# TRUE STEP: .
# Autocompleted STEP:  pasta according to package directions.  3 - Add salt and pepper to taste.", "4 - Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Chill several hours. Easy as pie to make.
# TRUE STEP: Chill several hours. Easy as pie to make.
# Autocompleted STEP:  Makes about 12 servings."]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Beat the eggs
# TRUE STEP: well and add to the vegetables.
# Autocompleted STEP:  2 - Combine the flour, salt and pepper in a small bowl and mix together well
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Return sieved berries
# TRUE STEP: to the kettle with whole berries and add sugar, mandarin juice, lemon juice and mandarin peel.
# Autocompleted STEP: ia their juice and salt to a blender. 3 - Add the juice and sugar. 4 - Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add oats and
# TRUE STEP: salt and mix well.
# Autocompleted STEP: iced water and stir until blended. 3 - Add nuts and stir until blended. 4 - Add sugar
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add salt, oil,
# TRUE STEP: yeast, 2 or 3 cups warm water and sugar.
# Autocompleted STEP:  pepper, pepper, and sugar.  3 - Add yeast mixture to flour mixture.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix and bake at 400\u00b0 for 1 hour. If desired, top with additional cheese.
# TRUE STEP: Mix and bake at 400\u00b0 for 1 hour. If desired, top with additional cheese.
# Autocompleted STEP:  Put in a bowl and serve."]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Remove the skin
# TRUE STEP: and bones from the fish. Saute the diced salt pork in a large pot until crisp.
# Autocompleted STEP: !"]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a bowl,
# TRUE STEP: toss the sweet potato, onions, oil, salt & pepper.
# Autocompleted STEP: iced butter, milk, and 1 teaspoon salt, beat egg whites until light and fluffy. Add bread
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Turn on a
# TRUE STEP: food processor fitted with the steel blade, and drop in the garlic.
# Autocompleted STEP: iced water bath, add in the salt, and stir to combine. 3 - Add in the pars
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: To use frozen
# TRUE STEP: soup: Thaw soup in the refrigerator overnight. Transfer to a saucepan. Cover and cook over medium heat until heated through.
# Autocompleted STEP: iced water, heat 1/2 cup olive oil in a medium-size saucepan over medium heat
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Lighly beat the
# TRUE STEP: eggs with a few dashes of salt in another bowl.
# Autocompleted STEP: iced water and add the shrimp and shrimp paste. Then add the rice noodles. Stir until the rice
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add jar sauce,
# TRUE STEP: wine and brown sugar; simer 15 minutes on medium-low heat.
# Autocompleted STEP: iced water, and salt to taste. 3 - Add mushrooms, onions, and garlic.  4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Serves 4
# TRUE STEP: .
# Autocompleted STEP: . (Can be prepared ahead.)"]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Cut oysters and saute with shrimp, shallots, garlic and butter in a skillet on medium heat for 10 minutes, constantly stirring.
# TRUE STEP: Cut oysters and saute with shrimp, shallots, garlic and butter in a skillet on medium heat for 10 minutes, constantly stirring.
# Autocompleted STEP:  Drain and set aside.", "2 - Add mushrooms, halved, and garlic and butter in a
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Place potatoes over
# TRUE STEP: medium hot grill and cook, turning every 15 minutes or so, until tender when pierced with a fork.
# Autocompleted STEP: iced water and cook until tender. Then add salt and pepper. 3 - Add salt and pepper and
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a large
# TRUE STEP: heavy bottom sauce pan bring the 5 and 1/4C water to a BOIL.
# Autocompleted STEP: iced iced iced iced iced iced iced iced pot add the salt &
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour in two
# TRUE STEP: cups of peanuts or pecan halves and stir constantly until syrup begins to harden. Pour out on waxed paper and separate halves and allow to cool.
# Autocompleted STEP: iced water glasses.  3 - Add the first 4 ingredients.  4 - Add the second 4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Layer half the cake cubes into a trifle bowl or glass serving dish. Top cake cubes with half the pudding, half the blueberries, and half the whipped topping. Repeat layers; cover and refrigerate 4 hours before serving.
# TRUE STEP: Layer half the cake cubes into a trifle bowl or glass serving dish. Top cake cubes with half the pudding, half the blueberries, and half the whipped topping. Repeat layers; cover and refrigerate 4 hours before serving.
# Autocompleted STEP:  This will keep for at least 3 days.", "2 - Top with 2 more cherries; garn
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add onions and
# TRUE STEP: cook
# Autocompleted STEP: ids and add ground beef and 2 cups water. Cook, stirring occasionally, until onions are translucent,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add salt and
# TRUE STEP: pepper, then meat stock; stir until mixture bubbles.
# Autocompleted STEP: iced water and saute 5 min.", "3- Add garlic and cook until softened, stirring occasionally
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Combine dressing and
# TRUE STEP: sauerkraut.
# Autocompleted STEP: iced water in a large bowl.", "3 - Add to the dough and knead until smooth.
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour over strawberries.
# TRUE STEP: Place in baked pie shells.
# Autocompleted STEP: !"]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Pour 1/4 cup
# TRUE STEP: of dressing over watercress, toss well and arrange on individual salad plates. Garnish with red pepper strips. Serve remaining dressing on the side. Or serve salad in a large bowl with dressing on the side.
# Autocompleted STEP: iced watercress into a large pot of boiling salted water. Bring to a boil and bring
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Transfer cauliflower and
# TRUE STEP: peas to a bowl and add coconut, curry powder, cayenne or paprika, cilantro, lemon juice and salt.
# Autocompleted STEP: iced water to a shallow bowl.  3 - Add salt and pepper to taste.  4 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Use to spoon
# TRUE STEP: over citrus, bananas, kiwi, fresh apricots, peaches and nectarines
# Autocompleted STEP: iced syrup over the top of the noodles. Serve with fresh fruit, fresh, fresh, fresh,
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Rub chicken breasts
# TRUE STEP: with remaining teaspoon of olive oil, and season with salt and pepper to taste. Arrange chicken skin-side up among peaches and onions.
# Autocompleted STEP: ..........................", "1 lb ground beef, cooked and drained", "2 cloves garlic, minced",
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with:
# TRUE STEP:
# Autocompleted STEP:  Heat a large pot of boiling water, add the egg whites and cook until heated through. Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: In a large bowl, cream butter and sugar together. Add eggs, bananas, buttermilk and vanilla until the batter is well mixed. Add in the flour, baking powder, salt and baking soda. Mix until well combined. Divide batter into greased and floured bread pans and bake at 350 degrees F for 50-55 minutes or until a toothpick comes out clean.
# TRUE STEP: In a large bowl, cream butter and sugar together. Add eggs, bananas, buttermilk and vanilla until the batter is well mixed. Add in the flour, baking powder, salt and baking soda. Mix until well combined. Divide batter into greased and floured bread pans and bake at 350 degrees F for 50-55 minutes or until a toothpick comes out clean.
# Autocompleted STEP:  (I usually bake at 350 degrees F for 10 minutes.)", "3 - Grease and flour
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Beat egg yolks
# TRUE STEP: and pour part of milk mixture over them.
# Autocompleted STEP: --------------- 5 minutes. Add milk and vanilla. Stir in egg whites, stirring until well blended. Add
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Turn dough out
# TRUE STEP: onto floured surface; knead lightly.
# Autocompleted STEP: ipsumpling.  3 - Set aside.", "1. In a large bowl, combine flour
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Combine flour, salt
# TRUE STEP: and baking soda; add to mixture.
# Autocompleted STEP: ", "3/4 c. butter, egg, milk and vanilla; mix well. 3 -
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Spread dough on
# TRUE STEP: lightly greased cookie sheet.
# Autocompleted STEP: iced mushrooms.  3 - Cook until browned, stirring occasionally.", "4 - Pour remaining ingredients
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Heat the honey
# TRUE STEP: in a small saucepan over low heat until less gooey and more liqudiy.
# Autocompleted STEP: ids in a saucepan.  3 - Add the flour mixture to the butter and stir until it
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Slice beef very
# TRUE STEP: thinly against the grain.
# Autocompleted STEP:  shortly.  3 - Strain into a large bowl.  4 - Add half
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: One tenderloin at
# TRUE STEP: a time, cover in flour, move to the buffalo sauce and cover totally with sauce, and immediately cover in the bread crumbs.
# Autocompleted STEP:  the time, cook the beef to medium heat. 3 - Add the chicken, stir-f
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Add vegetables and
# TRUE STEP: pineapple to the marinade. Let stand at least 10 minutes before skewering.
# Autocompleted STEP: iced water (or possibly 1/2 cup water) to skewers.", "3 - Add tomatoes
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Mix the lemon
# TRUE STEP: juice vigorously with the oil and season it to taste. Toss the salad with the vinaigrette, and leave it for 30 mins to marinate before serving. Serve with crusty bread, garnished with whole pickled peppers.
# Autocompleted STEP: iced water, cottage cheese, cottage cheese mixture, lemon juice, salt and pepper in a large bowl
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Refrigerate until thickened
# TRUE STEP: but not set.
# Autocompleted STEP:  3 - Serve with whipped cream or chilled cream. !"]
#
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Drizzle with wine
# TRUE STEP: and sprinkle with garlic, dill and salt & pepper.
# Autocompleted STEP: !!! This will result in a smooth fillet, which will be thick and creamy. Add in the
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Top with half
# TRUE STEP: of the peaches, strawberries and blueberries. Spread evenly.
# Autocompleted STEP: iced water, 1/2 cup water and 1/4 cup sugar, and mix well. 3
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Clean them down
# TRUE STEP: to the hearts, following the
# Autocompleted STEP: iced.", "1 tablespoon (15ml) water", "3/4 cup (175ml)
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: Combine the peppers
# TRUE STEP: and chicken broth in a saucepan over medium-low heat; simmer 30 minutes.
# Autocompleted STEP:  and garlic in a large bowl.", "3 - Add the mushrooms to the pot and cook until
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: To serve, add
# TRUE STEP: a shot of brandy to a cup.
# Autocompleted STEP: iced water.  3 - To cook, add to the pan with the orange halves.  4
# --------------------------------------------------------------------------------
# Autocompleting the instruction step starting with: You will need a baking bag.
# TRUE STEP: You will need a baking bag.
# Autocompleted STEP:  You can use a spoon or a large pot.", "2 - Put 1/3 of the sauce

# %%
def calculate_perplexity(trained_model, model_name, original_prompt, rest_of_instruction_step):
    tokenizer = GPT2Tokenizer.from_pretrained(model_name)
    
    prompt_id = tokenizer(original_prompt, return_tensors='pt').input_ids
    completion_id = tokenizer(rest_of_instruction_step, return_tensors='pt').input_ids
    input_ids = torch.cat([prompt_id, completion_id], dim=-1)

    # Calculate log likelihood
    with torch.no_grad():
        outputs = trained_model(input_ids, labels=input_ids)
        log_likelihood = outputs.loss * completion_id.size(1)  # Total log likelihood

    perplexity = torch.exp(log_likelihood / completion_id.size(1))
    return perplexity.item()

# %%
for model_name in models:
    good_perp = calculate_perplexity(models[model_name], model_names[0], original_prompt, rest_of_instruction_step)
    print("Good Perplexity:", good_perp)

    bad_perp = calculate_perplexity(models[model_name], model_names[0], original_prompt, "preheat the oven to 1450 farheneight and put your baby in it")
    print("Bad Perplexity:", bad_perp)
# Out:
# Good Perplexity: 14.24428939819336
# Bad Perplexity: 18.544994354248047
# Good Perplexity: 17.390151977539062
# Bad Perplexity: 23.119401931762695
# Good Perplexity: 19.475215911865234
# Bad Perplexity: 25.78233528137207
# Good Perplexity: 17.962844848632812
# Bad Perplexity: 24.20036506652832
# Good Perplexity: 18.346912384033203
# Bad Perplexity: 24.704147338867188

# %%
def perplexity_across_dataset(trained_model, model_name, test_df, n_words_before_autocomplete=3, verbose=True):
    # This function 
    all_perplexity = []
    for i in range(len(test_df)):
        if verbose:
            print("Measuring perplexity on test recipe number: ", i)
        
        title, ingredients, steps, _, _ = separate_recipe_components(i)

        #recipe_index, n_complete_steps=2, n_words_before_autocomplete=3
        
        
        complete_steps = []
        for j in range(len(steps)):
            
            next_step = steps[j]
            n_characters_before_autocomplete = index_of_instruction_word(next_step, n_words_before_autocomplete)
            
            if n_characters_before_autocomplete >= len(next_step):
                continue
            
            incomplete_next_step = next_step[:n_characters_before_autocomplete]
            rest_of_instruction_step = next_step[n_characters_before_autocomplete:]
            
            prompt = make_prompt(title, ingredients, complete_steps, incomplete_next_step)
            perplexity = calculate_perplexity(trained_model, "./gpt2-finetuned-recipes-bakery", prompt, rest_of_instruction_step)
            
            all_perplexity.append(perplexity)
            if i < len(steps):
                complete_steps.append(steps[i])
    
    return sum(all_perplexity) / float(len(all_perplexity))
            

def eval_perplexity(trained_model, test_data, bad_data = False):
    
    if bad_data:
        return 0
    else:
        return perplexity_across_dataset(trained_model, test_data)

# %%
from contextlib import redirect_stdout

with open('output_DS[0].txt', 'w') as f:
    with redirect_stdout(f):
        for model_name in models:
            print(perplexity_across_dataset(models[model_name], model_name, df, n_words_before_autocomplete=3, verbose=True))

# %%
for model_name in models:
    print(perplexity_across_dataset(models[model_name], model_name, df, n_words_before_autocomplete=3, verbose=True))
# Out:
# Measuring perplexity on test recipe number:  0
# Measuring perplexity on test recipe number:  1
# Measuring perplexity on test recipe number:  2
# Measuring perplexity on test recipe number:  3
# Measuring perplexity on test recipe number:  4
# Measuring perplexity on test recipe number:  5
# Measuring perplexity on test recipe number:  6
# Measuring perplexity on test recipe number:  7
# Measuring perplexity on test recipe number:  8
# Measuring perplexity on test recipe number:  9
# Measuring perplexity on test recipe number:  10
# Measuring perplexity on test recipe number:  11
# Measuring perplexity on test recipe number:  12
# Measuring perplexity on test recipe number:  13
# Measuring perplexity on test recipe number:  14
# Measuring perplexity on test recipe number:  15
# Measuring perplexity on test recipe number:  16
# Measuring perplexity on test recipe number:  17
# Measuring perplexity on test recipe number:  18
# Measuring perplexity on test recipe number:  19
# Measuring perplexity on test recipe number:  20
# Measuring perplexity on test recipe number:  21
# Measuring perplexity on test recipe number:  22
# Measuring perplexity on test recipe number:  23
# Measuring perplexity on test recipe number:  24
# Measuring perplexity on test recipe number:  25
# Measuring perplexity on test recipe number:  26
# Measuring perplexity on test recipe number:  27
# Measuring perplexity on test recipe number:  28
# Measuring perplexity on test recipe number:  29
# Measuring perplexity on test recipe number:  30
# Measuring perplexity on test recipe number:  31
# Measuring perplexity on test recipe number:  32
# Measuring perplexity on test recipe number:  33
# Measuring perplexity on test recipe number:  34
# Measuring perplexity on test recipe number:  35
# Measuring perplexity on test recipe number:  36
# Measuring perplexity on test recipe number:  37
# Measuring perplexity on test recipe number:  38
# Measuring perplexity on test recipe number:  39
# Measuring perplexity on test recipe number:  40
# Measuring perplexity on test recipe number:  41
# Measuring perplexity on test recipe number:  42
# Measuring perplexity on test recipe number:  43
# Measuring perplexity on test recipe number:  44
# Measuring perplexity on test recipe number:  45
# Measuring perplexity on test recipe number:  46
# Measuring perplexity on test recipe number:  47
# Measuring perplexity on test recipe number:  48
# Measuring perplexity on test recipe number:  49
# Measuring perplexity on test recipe number:  50
# Measuring perplexity on test recipe number:  51
# Measuring perplexity on test recipe number:  52
# Measuring perplexity on test recipe number:  53
# Measuring perplexity on test recipe number:  54
# Measuring perplexity on test recipe number:  55
# Measuring perplexity on test recipe number:  56
# Measuring perplexity on test recipe number:  57
# Measuring perplexity on test recipe number:  58
# Measuring perplexity on test recipe number:  59
# Measuring perplexity on test recipe number:  60
# Measuring perplexity on test recipe number:  61
# Measuring perplexity on test recipe number:  62
# Measuring perplexity on test recipe number:  63
# Measuring perplexity on test recipe number:  64
# Measuring perplexity on test recipe number:  65
# Measuring perplexity on test recipe number:  66
# Measuring perplexity on test recipe number:  67
# Measuring perplexity on test recipe number:  68
# Measuring perplexity on test recipe number:  69
# Measuring perplexity on test recipe number:  70
# Measuring perplexity on test recipe number:  71
# Measuring perplexity on test recipe number:  72
# Measuring perplexity on test recipe number:  73
# Measuring perplexity on test recipe number:  74
# Measuring perplexity on test recipe number:  75
# Measuring perplexity on test recipe number:  76
# Measuring perplexity on test recipe number:  77
# Measuring perplexity on test recipe number:  78
# Measuring perplexity on test recipe number:  79
# Measuring perplexity on test recipe number:  80
# Measuring perplexity on test recipe number:  81
# Measuring perplexity on test recipe number:  82
# Measuring perplexity on test recipe number:  83
# Measuring perplexity on test recipe number:  84
# Measuring perplexity on test recipe number:  85
# Measuring perplexity on test recipe number:  86
# Measuring perplexity on test recipe number:  87
# Measuring perplexity on test recipe number:  88
# Measuring perplexity on test recipe number:  89
# Measuring perplexity on test recipe number:  90
# Measuring perplexity on test recipe number:  91
# Measuring perplexity on test recipe number:  92
# Measuring perplexity on test recipe number:  93
# Measuring perplexity on test recipe number:  94
# Measuring perplexity on test recipe number:  95
# Measuring perplexity on test recipe number:  96
# Measuring perplexity on test recipe number:  97
# Measuring perplexity on test recipe number:  98
# Measuring perplexity on test recipe number:  99
# Measuring perplexity on test recipe number:  100
# Measuring perplexity on test recipe number:  101
# Measuring perplexity on test recipe number:  102
# Measuring perplexity on test recipe number:  103
# Measuring perplexity on test recipe number:  104
# Measuring perplexity on test recipe number:  105
# Measuring perplexity on test recipe number:  106
# Measuring perplexity on test recipe number:  107
# Measuring perplexity on test recipe number:  108
# Measuring perplexity on test recipe number:  109
# Measuring perplexity on test recipe number:  110
# Measuring perplexity on test recipe number:  111
# Measuring perplexity on test recipe number:  112
# Measuring perplexity on test recipe number:  113
# Measuring perplexity on test recipe number:  114
# Measuring perplexity on test recipe number:  115
# Measuring perplexity on test recipe number:  116
# Measuring perplexity on test recipe number:  117
# Measuring perplexity on test recipe number:  118
# Measuring perplexity on test recipe number:  119
# Measuring perplexity on test recipe number:  120
# Measuring perplexity on test recipe number:  121
# Measuring perplexity on test recipe number:  122
# Measuring perplexity on test recipe number:  123
# Measuring perplexity on test recipe number:  124
# Measuring perplexity on test recipe number:  125
# Measuring perplexity on test recipe number:  126
# Measuring perplexity on test recipe number:  127
# Measuring perplexity on test recipe number:  128
# Measuring perplexity on test recipe number:  129
# Measuring perplexity on test recipe number:  130
# Measuring perplexity on test recipe number:  131
# Measuring perplexity on test recipe number:  132
# Measuring perplexity on test recipe number:  133
# Measuring perplexity on test recipe number:  134
# Measuring perplexity on test recipe number:  135
# Measuring perplexity on test recipe number:  136
# Measuring perplexity on test recipe number:  137
# Measuring perplexity on test recipe number:  138
# Measuring perplexity on test recipe number:  139
# Measuring perplexity on test recipe number:  140
# Measuring perplexity on test recipe number:  141
# Measuring perplexity on test recipe number:  142
# Measuring perplexity on test recipe number:  143
# Measuring perplexity on test recipe number:  144
# Measuring perplexity on test recipe number:  145
# Measuring perplexity on test recipe number:  146
# Measuring perplexity on test recipe number:  147
# Measuring perplexity on test recipe number:  148
# Measuring perplexity on test recipe number:  149
# Measuring perplexity on test recipe number:  150
# Measuring perplexity on test recipe number:  151
# Measuring perplexity on test recipe number:  152
# Measuring perplexity on test recipe number:  153
# Measuring perplexity on test recipe number:  154
# Measuring perplexity on test recipe number:  155
# Measuring perplexity on test recipe number:  156
# Measuring perplexity on test recipe number:  157
# Measuring perplexity on test recipe number:  158
# Measuring perplexity on test recipe number:  159
# Measuring perplexity on test recipe number:  160
# Measuring perplexity on test recipe number:  161
# Measuring perplexity on test recipe number:  162
# Measuring perplexity on test recipe number:  163
# Measuring perplexity on test recipe number:  164
# Measuring perplexity on test recipe number:  165
# Measuring perplexity on test recipe number:  166
# Measuring perplexity on test recipe number:  167
# Measuring perplexity on test recipe number:  168
# Measuring perplexity on test recipe number:  169
# Measuring perplexity on test recipe number:  170
# Measuring perplexity on test recipe number:  171
# Measuring perplexity on test recipe number:  172
# Measuring perplexity on test recipe number:  173
# Measuring perplexity on test recipe number:  174
# Measuring perplexity on test recipe number:  175
# Measuring perplexity on test recipe number:  176
# Measuring perplexity on test recipe number:  177
# Measuring perplexity on test recipe number:  178
# Measuring perplexity on test recipe number:  179
# Measuring perplexity on test recipe number:  180
# Measuring perplexity on test recipe number:  181
# Measuring perplexity on test recipe number:  182
# Measuring perplexity on test recipe number:  183
# Measuring perplexity on test recipe number:  184
# Measuring perplexity on test recipe number:  185
# Measuring perplexity on test recipe number:  186
# Measuring perplexity on test recipe number:  187
# Measuring perplexity on test recipe number:  188
# Measuring perplexity on test recipe number:  189
# Measuring perplexity on test recipe number:  190
# Measuring perplexity on test recipe number:  191
# Measuring perplexity on test recipe number:  192
# Measuring perplexity on test recipe number:  193
# Measuring perplexity on test recipe number:  194
# Measuring perplexity on test recipe number:  195
# Measuring perplexity on test recipe number:  196
# Measuring perplexity on test recipe number:  197
# Measuring perplexity on test recipe number:  198
# Measuring perplexity on test recipe number:  199
# Measuring perplexity on test recipe number:  200
# Measuring perplexity on test recipe number:  201
# Measuring perplexity on test recipe number:  202
# Measuring perplexity on test recipe number:  203
# Measuring perplexity on test recipe number:  204
# Measuring perplexity on test recipe number:  205
# Measuring perplexity on test recipe number:  206
# Measuring perplexity on test recipe number:  207
# Measuring perplexity on test recipe number:  208
# Measuring perplexity on test recipe number:  209
# Measuring perplexity on test recipe number:  210
# Measuring perplexity on test recipe number:  211
# Measuring perplexity on test recipe number:  212
# Measuring perplexity on test recipe number:  213
# Measuring perplexity on test recipe number:  214
# Measuring perplexity on test recipe number:  215
# Measuring perplexity on test recipe number:  216
# Measuring perplexity on test recipe number:  217
# Measuring perplexity on test recipe number:  218
# Measuring perplexity on test recipe number:  219
# Measuring perplexity on test recipe number:  220
# Measuring perplexity on test recipe number:  221
# Measuring perplexity on test recipe number:  222
# Measuring perplexity on test recipe number:  223
# Measuring perplexity on test recipe number:  224
# Measuring perplexity on test recipe number:  225
# Measuring perplexity on test recipe number:  226
# Measuring perplexity on test recipe number:  227
# Measuring perplexity on test recipe number:  228
# Measuring perplexity on test recipe number:  229
# Measuring perplexity on test recipe number:  230
# Measuring perplexity on test recipe number:  231
# Measuring perplexity on test recipe number:  232
# Measuring perplexity on test recipe number:  233
# Measuring perplexity on test recipe number:  234
# Measuring perplexity on test recipe number:  235
# Measuring perplexity on test recipe number:  236
# Measuring perplexity on test recipe number:  237
# Measuring perplexity on test recipe number:  238
# Measuring perplexity on test recipe number:  239
# Measuring perplexity on test recipe number:  240
# Measuring perplexity on test recipe number:  241
# Measuring perplexity on test recipe number:  242
# Measuring perplexity on test recipe number:  243
# Measuring perplexity on test recipe number:  244
# Measuring perplexity on test recipe number:  245
# Measuring perplexity on test recipe number:  246
# Measuring perplexity on test recipe number:  247
# Measuring perplexity on test recipe number:  248
# Measuring perplexity on test recipe number:  249
# Measuring perplexity on test recipe number:  250
# Measuring perplexity on test recipe number:  251
# Measuring perplexity on test recipe number:  252
# Measuring perplexity on test recipe number:  253
# Measuring perplexity on test recipe number:  254
# Measuring perplexity on test recipe number:  255
# Measuring perplexity on test recipe number:  256
# Measuring perplexity on test recipe number:  257
# Measuring perplexity on test recipe number:  258
# Measuring perplexity on test recipe number:  259
# Measuring perplexity on test recipe number:  260
# Measuring perplexity on test recipe number:  261
# Measuring perplexity on test recipe number:  262
# Measuring perplexity on test recipe number:  263
# Measuring perplexity on test recipe number:  264
# Measuring perplexity on test recipe number:  265
# Measuring perplexity on test recipe number:  266
# Measuring perplexity on test recipe number:  267
# Measuring perplexity on test recipe number:  268
# Measuring perplexity on test recipe number:  269
# Measuring perplexity on test recipe number:  270
# Measuring perplexity on test recipe number:  271
# Measuring perplexity on test recipe number:  272
# Measuring perplexity on test recipe number:  273
# Measuring perplexity on test recipe number:  274
# Measuring perplexity on test recipe number:  275
# Measuring perplexity on test recipe number:  276
# Measuring perplexity on test recipe number:  277
# Measuring perplexity on test recipe number:  278
# Measuring perplexity on test recipe number:  279
# Measuring perplexity on test recipe number:  280
# Measuring perplexity on test recipe number:  281
# Measuring perplexity on test recipe number:  282
# Measuring perplexity on test recipe number:  283
# Measuring perplexity on test recipe number:  284
# Measuring perplexity on test recipe number:  285
# Measuring perplexity on test recipe number:  286
# Measuring perplexity on test recipe number:  287
# Measuring perplexity on test recipe number:  288
# Measuring perplexity on test recipe number:  289
# Measuring perplexity on test recipe number:  290
# Measuring perplexity on test recipe number:  291
# Measuring perplexity on test recipe number:  292
# Measuring perplexity on test recipe number:  293
# Measuring perplexity on test recipe number:  294
# Measuring perplexity on test recipe number:  295
# Measuring perplexity on test recipe number:  296
# Measuring perplexity on test recipe number:  297
# Measuring perplexity on test recipe number:  298
# Measuring perplexity on test recipe number:  299
# Measuring perplexity on test recipe number:  300
# Measuring perplexity on test recipe number:  301
# Measuring perplexity on test recipe number:  302
# Measuring perplexity on test recipe number:  303
# Measuring perplexity on test recipe number:  304
# Measuring perplexity on test recipe number:  305
# Measuring perplexity on test recipe number:  306
# Measuring perplexity on test recipe number:  307
# Measuring perplexity on test recipe number:  308
# Measuring perplexity on test recipe number:  309
# Measuring perplexity on test recipe number:  310
# Measuring perplexity on test recipe number:  311
# Measuring perplexity on test recipe number:  312
# Measuring perplexity on test recipe number:  313
# Measuring perplexity on test recipe number:  314
# Measuring perplexity on test recipe number:  315
# Measuring perplexity on test recipe number:  316
# Measuring perplexity on test recipe number:  317
# Measuring perplexity on test recipe number:  318
# Measuring perplexity on test recipe number:  319
# Measuring perplexity on test recipe number:  320
# Measuring perplexity on test recipe number:  321
# Measuring perplexity on test recipe number:  322
# Measuring perplexity on test recipe number:  323
# Measuring perplexity on test recipe number:  324
# Measuring perplexity on test recipe number:  325
# Measuring perplexity on test recipe number:  326
# Measuring perplexity on test recipe number:  327
# Measuring perplexity on test recipe number:  328
# Measuring perplexity on test recipe number:  329
# Measuring perplexity on test recipe number:  330
# Measuring perplexity on test recipe number:  331
# Measuring perplexity on test recipe number:  332
# Measuring perplexity on test recipe number:  333
# Measuring perplexity on test recipe number:  334
# Measuring perplexity on test recipe number:  335
# Measuring perplexity on test recipe number:  336
# Measuring perplexity on test recipe number:  337
# Measuring perplexity on test recipe number:  338
# Measuring perplexity on test recipe number:  339
# Measuring perplexity on test recipe number:  340
# Measuring perplexity on test recipe number:  341
# Measuring perplexity on test recipe number:  342
# Measuring perplexity on test recipe number:  343
# Measuring perplexity on test recipe number:  344
# Measuring perplexity on test recipe number:  345
# Measuring perplexity on test recipe number:  346
# Measuring perplexity on test recipe number:  347
# Measuring perplexity on test recipe number:  348
# Measuring perplexity on test recipe number:  349
# Measuring perplexity on test recipe number:  350
# Measuring perplexity on test recipe number:  351
# Measuring perplexity on test recipe number:  352
# Measuring perplexity on test recipe number:  353
# Measuring perplexity on test recipe number:  354
# Measuring perplexity on test recipe number:  355
# Measuring perplexity on test recipe number:  356
# Measuring perplexity on test recipe number:  357
# Measuring perplexity on test recipe number:  358
# Measuring perplexity on test recipe number:  359
# Measuring perplexity on test recipe number:  360
# Measuring perplexity on test recipe number:  361
# Measuring perplexity on test recipe number:  362
# Measuring perplexity on test recipe number:  363
# Measuring perplexity on test recipe number:  364
# Measuring perplexity on test recipe number:  365
# Measuring perplexity on test recipe number:  366
# Measuring perplexity on test recipe number:  367
# Measuring perplexity on test recipe number:  368
# Measuring perplexity on test recipe number:  369
# Measuring perplexity on test recipe number:  370
# Measuring perplexity on test recipe number:  371
# Measuring perplexity on test recipe number:  372
# Measuring perplexity on test recipe number:  373
# Measuring perplexity on test recipe number:  374
# Measuring perplexity on test recipe number:  375
# Measuring perplexity on test recipe number:  376
# Measuring perplexity on test recipe number:  377
# Measuring perplexity on test recipe number:  378
# Measuring perplexity on test recipe number:  379
# Measuring perplexity on test recipe number:  380
# Measuring perplexity on test recipe number:  381
# Measuring perplexity on test recipe number:  382
# Measuring perplexity on test recipe number:  383
# Measuring perplexity on test recipe number:  384
# Measuring perplexity on test recipe number:  385
# Measuring perplexity on test recipe number:  386
# Measuring perplexity on test recipe number:  387
# Measuring perplexity on test recipe number:  388
# Measuring perplexity on test recipe number:  389
# Measuring perplexity on test recipe number:  390
# Measuring perplexity on test recipe number:  391
# Measuring perplexity on test recipe number:  392
# Measuring perplexity on test recipe number:  393
# Measuring perplexity on test recipe number:  394
# Measuring perplexity on test recipe number:  395
# Measuring perplexity on test recipe number:  396
# Measuring perplexity on test recipe number:  397
# Measuring perplexity on test recipe number:  398
# Measuring perplexity on test recipe number:  399
# Measuring perplexity on test recipe number:  400
# Measuring perplexity on test recipe number:  401
# Measuring perplexity on test recipe number:  402
# Measuring perplexity on test recipe number:  403
# Measuring perplexity on test recipe number:  404
# Measuring perplexity on test recipe number:  405
# Measuring perplexity on test recipe number:  406
# Measuring perplexity on test recipe number:  407
# Measuring perplexity on test recipe number:  408
# Measuring perplexity on test recipe number:  409
# Measuring perplexity on test recipe number:  410
# Measuring perplexity on test recipe number:  411
# Measuring perplexity on test recipe number:  412
# Measuring perplexity on test recipe number:  413
# Measuring perplexity on test recipe number:  414
# Measuring perplexity on test recipe number:  415
# Measuring perplexity on test recipe number:  416
# Measuring perplexity on test recipe number:  417
# Measuring perplexity on test recipe number:  418
# Measuring perplexity on test recipe number:  419
# Measuring perplexity on test recipe number:  420
# Measuring perplexity on test recipe number:  421
# Measuring perplexity on test recipe number:  422
# Measuring perplexity on test recipe number:  423
# Measuring perplexity on test recipe number:  424
# Measuring perplexity on test recipe number:  425
# Measuring perplexity on test recipe number:  426
# Measuring perplexity on test recipe number:  427
# Measuring perplexity on test recipe number:  428
# Measuring perplexity on test recipe number:  429
# Measuring perplexity on test recipe number:  430
# Measuring perplexity on test recipe number:  431
# Measuring perplexity on test recipe number:  432
# Measuring perplexity on test recipe number:  433
# Measuring perplexity on test recipe number:  434
# Measuring perplexity on test recipe number:  435
# Measuring perplexity on test recipe number:  436
# Measuring perplexity on test recipe number:  437
# Measuring perplexity on test recipe number:  438
# Measuring perplexity on test recipe number:  439
# Measuring perplexity on test recipe number:  440
# Measuring perplexity on test recipe number:  441
# Measuring perplexity on test recipe number:  442
# Measuring perplexity on test recipe number:  443
# Measuring perplexity on test recipe number:  444
# Measuring perplexity on test recipe number:  445
# Measuring perplexity on test recipe number:  446
# Measuring perplexity on test recipe number:  447
# Measuring perplexity on test recipe number:  448
# Measuring perplexity on test recipe number:  449
# Measuring perplexity on test recipe number:  450
# Measuring perplexity on test recipe number:  451
# Measuring perplexity on test recipe number:  452
# Measuring perplexity on test recipe number:  453
# Measuring perplexity on test recipe number:  454
# Measuring perplexity on test recipe number:  455
# Measuring perplexity on test recipe number:  456
# Measuring perplexity on test recipe number:  457
# Measuring perplexity on test recipe number:  458
# Measuring perplexity on test recipe number:  459
# Measuring perplexity on test recipe number:  460
# Measuring perplexity on test recipe number:  461
# Measuring perplexity on test recipe number:  462
# Measuring perplexity on test recipe number:  463
# Measuring perplexity on test recipe number:  464
# Measuring perplexity on test recipe number:  465
# Measuring perplexity on test recipe number:  466
# Measuring perplexity on test recipe number:  467
# Measuring perplexity on test recipe number:  468
# Measuring perplexity on test recipe number:  469
# Measuring perplexity on test recipe number:  470
# Measuring perplexity on test recipe number:  471
# Measuring perplexity on test recipe number:  472
# Measuring perplexity on test recipe number:  473
# Measuring perplexity on test recipe number:  474
# Measuring perplexity on test recipe number:  475
# Measuring perplexity on test recipe number:  476
# Measuring perplexity on test recipe number:  477
# Measuring perplexity on test recipe number:  478
# Measuring perplexity on test recipe number:  479
# Measuring perplexity on test recipe number:  480
# Measuring perplexity on test recipe number:  481
# Measuring perplexity on test recipe number:  482
# Measuring perplexity on test recipe number:  483
# Measuring perplexity on test recipe number:  484
# Measuring perplexity on test recipe number:  485
# Measuring perplexity on test recipe number:  486
# Measuring perplexity on test recipe number:  487
# Measuring perplexity on test recipe number:  488
# Measuring perplexity on test recipe number:  489
# Measuring perplexity on test recipe number:  490
# Measuring perplexity on test recipe number:  491
# Measuring perplexity on test recipe number:  492
# Measuring perplexity on test recipe number:  493
# Measuring perplexity on test recipe number:  494
# Measuring perplexity on test recipe number:  495
# Measuring perplexity on test recipe number:  496
# Measuring perplexity on test recipe number:  497
# Measuring perplexity on test recipe number:  498
# Measuring perplexity on test recipe number:  499
# 25.342700860019406
# Measuring perplexity on test recipe number:  0
# Measuring perplexity on test recipe number:  1
# Measuring perplexity on test recipe number:  2
# Measuring perplexity on test recipe number:  3
# Measuring perplexity on test recipe number:  4
# Measuring perplexity on test recipe number:  5
# Measuring perplexity on test recipe number:  6
# Measuring perplexity on test recipe number:  7
# Measuring perplexity on test recipe number:  8
# Measuring perplexity on test recipe number:  9
# Measuring perplexity on test recipe number:  10
# Measuring perplexity on test recipe number:  11
# Measuring perplexity on test recipe number:  12
# Measuring perplexity on test recipe number:  13
# Measuring perplexity on test recipe number:  14
# Measuring perplexity on test recipe number:  15
# Measuring perplexity on test recipe number:  16
# Measuring perplexity on test recipe number:  17
# Measuring perplexity on test recipe number:  18
# Measuring perplexity on test recipe number:  19
# Measuring perplexity on test recipe number:  20
# Measuring perplexity on test recipe number:  21
# Measuring perplexity on test recipe number:  22
# Measuring perplexity on test recipe number:  23
# Measuring perplexity on test recipe number:  24
# Measuring perplexity on test recipe number:  25
# Measuring perplexity on test recipe number:  26
# Measuring perplexity on test recipe number:  27
# Measuring perplexity on test recipe number:  28
# Measuring perplexity on test recipe number:  29
# Measuring perplexity on test recipe number:  30
# Measuring perplexity on test recipe number:  31
# Measuring perplexity on test recipe number:  32
# Measuring perplexity on test recipe number:  33
# Measuring perplexity on test recipe number:  34
# Measuring perplexity on test recipe number:  35
# Measuring perplexity on test recipe number:  36
# Measuring perplexity on test recipe number:  37
# Measuring perplexity on test recipe number:  38
# Measuring perplexity on test recipe number:  39
# Measuring perplexity on test recipe number:  40
# Measuring perplexity on test recipe number:  41
# Measuring perplexity on test recipe number:  42
# Measuring perplexity on test recipe number:  43
# Measuring perplexity on test recipe number:  44
# Measuring perplexity on test recipe number:  45
# Measuring perplexity on test recipe number:  46
# Measuring perplexity on test recipe number:  47
# Measuring perplexity on test recipe number:  48
# Measuring perplexity on test recipe number:  49
# Measuring perplexity on test recipe number:  50
# Measuring perplexity on test recipe number:  51
# Measuring perplexity on test recipe number:  52
# Measuring perplexity on test recipe number:  53
# Measuring perplexity on test recipe number:  54
# Measuring perplexity on test recipe number:  55
# Measuring perplexity on test recipe number:  56
# Measuring perplexity on test recipe number:  57
# Measuring perplexity on test recipe number:  58
# Measuring perplexity on test recipe number:  59
# Measuring perplexity on test recipe number:  60
# Measuring perplexity on test recipe number:  61
# Measuring perplexity on test recipe number:  62
# Measuring perplexity on test recipe number:  63
# Measuring perplexity on test recipe number:  64
# Measuring perplexity on test recipe number:  65
# Measuring perplexity on test recipe number:  66
# Measuring perplexity on test recipe number:  67
# Measuring perplexity on test recipe number:  68
# Measuring perplexity on test recipe number:  69
# Measuring perplexity on test recipe number:  70
# Measuring perplexity on test recipe number:  71
# Measuring perplexity on test recipe number:  72
# Measuring perplexity on test recipe number:  73
# Measuring perplexity on test recipe number:  74
# Measuring perplexity on test recipe number:  75
# Measuring perplexity on test recipe number:  76
# Measuring perplexity on test recipe number:  77
# Measuring perplexity on test recipe number:  78
# Measuring perplexity on test recipe number:  79
# Measuring perplexity on test recipe number:  80
# Measuring perplexity on test recipe number:  81
# Measuring perplexity on test recipe number:  82
# Measuring perplexity on test recipe number:  83
# Measuring perplexity on test recipe number:  84
# Measuring perplexity on test recipe number:  85
# Measuring perplexity on test recipe number:  86
# Measuring perplexity on test recipe number:  87
# Measuring perplexity on test recipe number:  88
# Measuring perplexity on test recipe number:  89
# Measuring perplexity on test recipe number:  90
# Measuring perplexity on test recipe number:  91
# Measuring perplexity on test recipe number:  92
# Measuring perplexity on test recipe number:  93
# Measuring perplexity on test recipe number:  94
# Measuring perplexity on test recipe number:  95
# Measuring perplexity on test recipe number:  96
# Measuring perplexity on test recipe number:  97
# Measuring perplexity on test recipe number:  98
# Measuring perplexity on test recipe number:  99
# Measuring perplexity on test recipe number:  100
# Measuring perplexity on test recipe number:  101
# Measuring perplexity on test recipe number:  102
# Measuring perplexity on test recipe number:  103
# Measuring perplexity on test recipe number:  104
# Measuring perplexity on test recipe number:  105
# Measuring perplexity on test recipe number:  106
# Measuring perplexity on test recipe number:  107
# Measuring perplexity on test recipe number:  108
# Measuring perplexity on test recipe number:  109
# Measuring perplexity on test recipe number:  110
# Measuring perplexity on test recipe number:  111
# Measuring perplexity on test recipe number:  112
# Measuring perplexity on test recipe number:  113
# Measuring perplexity on test recipe number:  114
# Measuring perplexity on test recipe number:  115
# Measuring perplexity on test recipe number:  116
# Measuring perplexity on test recipe number:  117
# Measuring perplexity on test recipe number:  118
# Measuring perplexity on test recipe number:  119
# Measuring perplexity on test recipe number:  120
# Measuring perplexity on test recipe number:  121
# Measuring perplexity on test recipe number:  122
# Measuring perplexity on test recipe number:  123
# Measuring perplexity on test recipe number:  124
# Measuring perplexity on test recipe number:  125
# Measuring perplexity on test recipe number:  126
# Measuring perplexity on test recipe number:  127
# Measuring perplexity on test recipe number:  128
# Measuring perplexity on test recipe number:  129
# Measuring perplexity on test recipe number:  130
# Measuring perplexity on test recipe number:  131
# Measuring perplexity on test recipe number:  132
# Measuring perplexity on test recipe number:  133
# Measuring perplexity on test recipe number:  134
# Measuring perplexity on test recipe number:  135
# Measuring perplexity on test recipe number:  136
# Measuring perplexity on test recipe number:  137
# Measuring perplexity on test recipe number:  138
# Measuring perplexity on test recipe number:  139
# Measuring perplexity on test recipe number:  140
# Measuring perplexity on test recipe number:  141
# Measuring perplexity on test recipe number:  142
# Measuring perplexity on test recipe number:  143
# Measuring perplexity on test recipe number:  144
# Measuring perplexity on test recipe number:  145
# Measuring perplexity on test recipe number:  146
# Measuring perplexity on test recipe number:  147
# Measuring perplexity on test recipe number:  148
# Measuring perplexity on test recipe number:  149
# Measuring perplexity on test recipe number:  150
# Measuring perplexity on test recipe number:  151
# Measuring perplexity on test recipe number:  152
# Measuring perplexity on test recipe number:  153
# Measuring perplexity on test recipe number:  154
# Measuring perplexity on test recipe number:  155
# Measuring perplexity on test recipe number:  156
# Measuring perplexity on test recipe number:  157
# Measuring perplexity on test recipe number:  158
# Measuring perplexity on test recipe number:  159
# Measuring perplexity on test recipe number:  160
# Measuring perplexity on test recipe number:  161
# Measuring perplexity on test recipe number:  162
# Measuring perplexity on test recipe number:  163
# Measuring perplexity on test recipe number:  164
# Measuring perplexity on test recipe number:  165
# Measuring perplexity on test recipe number:  166
# Measuring perplexity on test recipe number:  167
# Measuring perplexity on test recipe number:  168
# Measuring perplexity on test recipe number:  169
# Measuring perplexity on test recipe number:  170
# Measuring perplexity on test recipe number:  171
# Measuring perplexity on test recipe number:  172
# Measuring perplexity on test recipe number:  173
# Measuring perplexity on test recipe number:  174
# Measuring perplexity on test recipe number:  175
# Measuring perplexity on test recipe number:  176
# Measuring perplexity on test recipe number:  177
# Measuring perplexity on test recipe number:  178
# Measuring perplexity on test recipe number:  179
# Measuring perplexity on test recipe number:  180
# Measuring perplexity on test recipe number:  181
# Measuring perplexity on test recipe number:  182
# Measuring perplexity on test recipe number:  183
# Measuring perplexity on test recipe number:  184
# Measuring perplexity on test recipe number:  185
# Measuring perplexity on test recipe number:  186
# Measuring perplexity on test recipe number:  187
# Measuring perplexity on test recipe number:  188
# Measuring perplexity on test recipe number:  189
# Measuring perplexity on test recipe number:  190
# Measuring perplexity on test recipe number:  191
# Measuring perplexity on test recipe number:  192
# Measuring perplexity on test recipe number:  193
# Measuring perplexity on test recipe number:  194
# Measuring perplexity on test recipe number:  195
# Measuring perplexity on test recipe number:  196
# Measuring perplexity on test recipe number:  197
# Measuring perplexity on test recipe number:  198
# Measuring perplexity on test recipe number:  199
# Measuring perplexity on test recipe number:  200
# Measuring perplexity on test recipe number:  201
# Measuring perplexity on test recipe number:  202
# Measuring perplexity on test recipe number:  203
# Measuring perplexity on test recipe number:  204
# Measuring perplexity on test recipe number:  205
# Measuring perplexity on test recipe number:  206
# Measuring perplexity on test recipe number:  207
# Measuring perplexity on test recipe number:  208
# Measuring perplexity on test recipe number:  209
# Measuring perplexity on test recipe number:  210
# Measuring perplexity on test recipe number:  211
# Measuring perplexity on test recipe number:  212
# Measuring perplexity on test recipe number:  213
# Measuring perplexity on test recipe number:  214
# Measuring perplexity on test recipe number:  215
# Measuring perplexity on test recipe number:  216
# Measuring perplexity on test recipe number:  217
# Measuring perplexity on test recipe number:  218
# Measuring perplexity on test recipe number:  219
# Measuring perplexity on test recipe number:  220
# Measuring perplexity on test recipe number:  221
# Measuring perplexity on test recipe number:  222
# Measuring perplexity on test recipe number:  223
# Measuring perplexity on test recipe number:  224
# Measuring perplexity on test recipe number:  225
# Measuring perplexity on test recipe number:  226
# Measuring perplexity on test recipe number:  227
# Measuring perplexity on test recipe number:  228
# Measuring perplexity on test recipe number:  229
# Measuring perplexity on test recipe number:  230
# Measuring perplexity on test recipe number:  231
# Measuring perplexity on test recipe number:  232
# Measuring perplexity on test recipe number:  233
# Measuring perplexity on test recipe number:  234
# Measuring perplexity on test recipe number:  235
# Measuring perplexity on test recipe number:  236
# Measuring perplexity on test recipe number:  237
# Measuring perplexity on test recipe number:  238
# Measuring perplexity on test recipe number:  239
# Measuring perplexity on test recipe number:  240
# Measuring perplexity on test recipe number:  241
# Measuring perplexity on test recipe number:  242
# Measuring perplexity on test recipe number:  243
# Measuring perplexity on test recipe number:  244
# Measuring perplexity on test recipe number:  245
# Measuring perplexity on test recipe number:  246
# Measuring perplexity on test recipe number:  247
# Measuring perplexity on test recipe number:  248
# Measuring perplexity on test recipe number:  249
# Measuring perplexity on test recipe number:  250
# Measuring perplexity on test recipe number:  251
# Measuring perplexity on test recipe number:  252
# Measuring perplexity on test recipe number:  253
# Measuring perplexity on test recipe number:  254
# Measuring perplexity on test recipe number:  255
# Measuring perplexity on test recipe number:  256
# Measuring perplexity on test recipe number:  257
# Measuring perplexity on test recipe number:  258
# Measuring perplexity on test recipe number:  259
# Measuring perplexity on test recipe number:  260
# Measuring perplexity on test recipe number:  261
# Measuring perplexity on test recipe number:  262
# Measuring perplexity on test recipe number:  263
# Measuring perplexity on test recipe number:  264
# Measuring perplexity on test recipe number:  265
# Measuring perplexity on test recipe number:  266
# Measuring perplexity on test recipe number:  267
# Measuring perplexity on test recipe number:  268
# Measuring perplexity on test recipe number:  269
# Measuring perplexity on test recipe number:  270
# Measuring perplexity on test recipe number:  271
# Measuring perplexity on test recipe number:  272
# Measuring perplexity on test recipe number:  273
# Measuring perplexity on test recipe number:  274
# Measuring perplexity on test recipe number:  275
# Measuring perplexity on test recipe number:  276
# Measuring perplexity on test recipe number:  277
# Measuring perplexity on test recipe number:  278
# Measuring perplexity on test recipe number:  279
# Measuring perplexity on test recipe number:  280
# Measuring perplexity on test recipe number:  281
# Measuring perplexity on test recipe number:  282
# Measuring perplexity on test recipe number:  283
# Measuring perplexity on test recipe number:  284
# Measuring perplexity on test recipe number:  285
# Measuring perplexity on test recipe number:  286
# Measuring perplexity on test recipe number:  287
# Measuring perplexity on test recipe number:  288
# Measuring perplexity on test recipe number:  289
# Measuring perplexity on test recipe number:  290
# Measuring perplexity on test recipe number:  291
# Measuring perplexity on test recipe number:  292
# Measuring perplexity on test recipe number:  293
# Measuring perplexity on test recipe number:  294
# Measuring perplexity on test recipe number:  295
# Measuring perplexity on test recipe number:  296
# Measuring perplexity on test recipe number:  297
# Measuring perplexity on test recipe number:  298
# Measuring perplexity on test recipe number:  299
# Measuring perplexity on test recipe number:  300
# Measuring perplexity on test recipe number:  301
# Measuring perplexity on test recipe number:  302
# Measuring perplexity on test recipe number:  303
# Measuring perplexity on test recipe number:  304
# Measuring perplexity on test recipe number:  305
# Measuring perplexity on test recipe number:  306
# Measuring perplexity on test recipe number:  307
# Measuring perplexity on test recipe number:  308
# Measuring perplexity on test recipe number:  309
# Measuring perplexity on test recipe number:  310
# Measuring perplexity on test recipe number:  311
# Measuring perplexity on test recipe number:  312
# Measuring perplexity on test recipe number:  313
# Measuring perplexity on test recipe number:  314
# Measuring perplexity on test recipe number:  315
# Measuring perplexity on test recipe number:  316
# Measuring perplexity on test recipe number:  317
# Measuring perplexity on test recipe number:  318
# Measuring perplexity on test recipe number:  319
# Measuring perplexity on test recipe number:  320
# Measuring perplexity on test recipe number:  321
# Measuring perplexity on test recipe number:  322
# Measuring perplexity on test recipe number:  323
# Measuring perplexity on test recipe number:  324
# Measuring perplexity on test recipe number:  325
# Measuring perplexity on test recipe number:  326
# Measuring perplexity on test recipe number:  327
# Measuring perplexity on test recipe number:  328
# Measuring perplexity on test recipe number:  329
# Measuring perplexity on test recipe number:  330
# Measuring perplexity on test recipe number:  331
# Measuring perplexity on test recipe number:  332
# Measuring perplexity on test recipe number:  333
# Measuring perplexity on test recipe number:  334
# Measuring perplexity on test recipe number:  335
# Measuring perplexity on test recipe number:  336
# Measuring perplexity on test recipe number:  337
# Measuring perplexity on test recipe number:  338
# Measuring perplexity on test recipe number:  339
# Measuring perplexity on test recipe number:  340
# Measuring perplexity on test recipe number:  341
# Measuring perplexity on test recipe number:  342
# Measuring perplexity on test recipe number:  343
# Measuring perplexity on test recipe number:  344
# Measuring perplexity on test recipe number:  345
# Measuring perplexity on test recipe number:  346
# Measuring perplexity on test recipe number:  347
# Measuring perplexity on test recipe number:  348
# Measuring perplexity on test recipe number:  349
# Measuring perplexity on test recipe number:  350
# Measuring perplexity on test recipe number:  351
# Measuring perplexity on test recipe number:  352
# Measuring perplexity on test recipe number:  353
# Measuring perplexity on test recipe number:  354
# Measuring perplexity on test recipe number:  355
# Measuring perplexity on test recipe number:  356
# Measuring perplexity on test recipe number:  357
# Measuring perplexity on test recipe number:  358
# Measuring perplexity on test recipe number:  359
# Measuring perplexity on test recipe number:  360
# Measuring perplexity on test recipe number:  361
# Measuring perplexity on test recipe number:  362
# Measuring perplexity on test recipe number:  363
# Measuring perplexity on test recipe number:  364
# Measuring perplexity on test recipe number:  365
# Measuring perplexity on test recipe number:  366
# Measuring perplexity on test recipe number:  367
# Measuring perplexity on test recipe number:  368
# Measuring perplexity on test recipe number:  369
# Measuring perplexity on test recipe number:  370
# Measuring perplexity on test recipe number:  371
# Measuring perplexity on test recipe number:  372
# Measuring perplexity on test recipe number:  373
# Measuring perplexity on test recipe number:  374
# Measuring perplexity on test recipe number:  375
# Measuring perplexity on test recipe number:  376
# Measuring perplexity on test recipe number:  377
# Measuring perplexity on test recipe number:  378
# Measuring perplexity on test recipe number:  379
# Measuring perplexity on test recipe number:  380
# Measuring perplexity on test recipe number:  381
# Measuring perplexity on test recipe number:  382
# Measuring perplexity on test recipe number:  383
# Measuring perplexity on test recipe number:  384
# Measuring perplexity on test recipe number:  385
# Measuring perplexity on test recipe number:  386
# Measuring perplexity on test recipe number:  387
# Measuring perplexity on test recipe number:  388
# Measuring perplexity on test recipe number:  389
# Measuring perplexity on test recipe number:  390
# Measuring perplexity on test recipe number:  391
# Measuring perplexity on test recipe number:  392
# Measuring perplexity on test recipe number:  393
# Measuring perplexity on test recipe number:  394
# Measuring perplexity on test recipe number:  395
# Measuring perplexity on test recipe number:  396
# Measuring perplexity on test recipe number:  397
# Measuring perplexity on test recipe number:  398
# Measuring perplexity on test recipe number:  399
# Measuring perplexity on test recipe number:  400
# Measuring perplexity on test recipe number:  401
# Measuring perplexity on test recipe number:  402
# Measuring perplexity on test recipe number:  403
# Measuring perplexity on test recipe number:  404
# Measuring perplexity on test recipe number:  405
# Measuring perplexity on test recipe number:  406
# Measuring perplexity on test recipe number:  407
# Measuring perplexity on test recipe number:  408
# Measuring perplexity on test recipe number:  409
# Measuring perplexity on test recipe number:  410
# Measuring perplexity on test recipe number:  411
# Measuring perplexity on test recipe number:  412
# Measuring perplexity on test recipe number:  413
# Measuring perplexity on test recipe number:  414
# Measuring perplexity on test recipe number:  415
# Measuring perplexity on test recipe number:  416
# Measuring perplexity on test recipe number:  417
# Measuring perplexity on test recipe number:  418
# Measuring perplexity on test recipe number:  419
# Measuring perplexity on test recipe number:  420
# Measuring perplexity on test recipe number:  421
# Measuring perplexity on test recipe number:  422
# Measuring perplexity on test recipe number:  423
# Measuring perplexity on test recipe number:  424
# Measuring perplexity on test recipe number:  425
# Measuring perplexity on test recipe number:  426
# Measuring perplexity on test recipe number:  427
# Measuring perplexity on test recipe number:  428
# Measuring perplexity on test recipe number:  429
# Measuring perplexity on test recipe number:  430
# Measuring perplexity on test recipe number:  431
# Measuring perplexity on test recipe number:  432
# Measuring perplexity on test recipe number:  433
# Measuring perplexity on test recipe number:  434
# Measuring perplexity on test recipe number:  435
# Measuring perplexity on test recipe number:  436
# Measuring perplexity on test recipe number:  437
# Measuring perplexity on test recipe number:  438
# Measuring perplexity on test recipe number:  439
# Measuring perplexity on test recipe number:  440
# Measuring perplexity on test recipe number:  441
# Measuring perplexity on test recipe number:  442
# Measuring perplexity on test recipe number:  443
# Measuring perplexity on test recipe number:  444
# Measuring perplexity on test recipe number:  445
# Measuring perplexity on test recipe number:  446
# Measuring perplexity on test recipe number:  447
# Measuring perplexity on test recipe number:  448
# Measuring perplexity on test recipe number:  449
# Measuring perplexity on test recipe number:  450
# Measuring perplexity on test recipe number:  451
# Measuring perplexity on test recipe number:  452
# Measuring perplexity on test recipe number:  453
# Measuring perplexity on test recipe number:  454
# Measuring perplexity on test recipe number:  455
# Measuring perplexity on test recipe number:  456
# Measuring perplexity on test recipe number:  457
# Measuring perplexity on test recipe number:  458
# Measuring perplexity on test recipe number:  459
# Measuring perplexity on test recipe number:  460
# Measuring perplexity on test recipe number:  461
# Measuring perplexity on test recipe number:  462
# Measuring perplexity on test recipe number:  463
# Measuring perplexity on test recipe number:  464
# Measuring perplexity on test recipe number:  465
# Measuring perplexity on test recipe number:  466
# Measuring perplexity on test recipe number:  467
# Measuring perplexity on test recipe number:  468
# Measuring perplexity on test recipe number:  469
# Measuring perplexity on test recipe number:  470
# Measuring perplexity on test recipe number:  471
# Measuring perplexity on test recipe number:  472
# Measuring perplexity on test recipe number:  473
# Measuring perplexity on test recipe number:  474
# Measuring perplexity on test recipe number:  475
# Measuring perplexity on test recipe number:  476
# Measuring perplexity on test recipe number:  477
# Measuring perplexity on test recipe number:  478
# Measuring perplexity on test recipe number:  479
# Measuring perplexity on test recipe number:  480
# Measuring perplexity on test recipe number:  481
# Measuring perplexity on test recipe number:  482
# ...
# Measuring perplexity on test recipe number:  174
# Measuring perplexity on test recipe number:  175
# Measuring perplexity on test recipe number:  176
# Measuring perplexity on test recipe number:  177
# Measuring perplexity on test recipe number:  178
# Measuring perplexity on test recipe number:  179
# Measuring perplexity on test recipe number:  180
# Measuring perplexity on test recipe number:  181
# Measuring perplexity on test recipe number:  182
# Measuring perplexity on test recipe number:  183
# Measuring perplexity on test recipe number:  184
# Measuring perplexity on test recipe number:  185
# Measuring perplexity on test recipe number:  186
# Measuring perplexity on test recipe number:  187
# Measuring perplexity on test recipe number:  188
# Measuring perplexity on test recipe number:  189
# Measuring perplexity on test recipe number:  190
# Measuring perplexity on test recipe number:  191
# Measuring perplexity on test recipe number:  192
# Measuring perplexity on test recipe number:  193
# Measuring perplexity on test recipe number:  194
# Measuring perplexity on test recipe number:  195
# Measuring perplexity on test recipe number:  196
# Measuring perplexity on test recipe number:  197
# Measuring perplexity on test recipe number:  198
# Measuring perplexity on test recipe number:  199
# Measuring perplexity on test recipe number:  200
# Measuring perplexity on test recipe number:  201
# Measuring perplexity on test recipe number:  202
# Measuring perplexity on test recipe number:  203
# Measuring perplexity on test recipe number:  204
# Measuring perplexity on test recipe number:  205
# Measuring perplexity on test recipe number:  206
# Measuring perplexity on test recipe number:  207
# Measuring perplexity on test recipe number:  208
# Measuring perplexity on test recipe number:  209
# Measuring perplexity on test recipe number:  210
# Measuring perplexity on test recipe number:  211
# Measuring perplexity on test recipe number:  212
# Measuring perplexity on test recipe number:  213
# Measuring perplexity on test recipe number:  214
# Measuring perplexity on test recipe number:  215
# Measuring perplexity on test recipe number:  216
# Measuring perplexity on test recipe number:  217
# Measuring perplexity on test recipe number:  218
# Measuring perplexity on test recipe number:  219
# Measuring perplexity on test recipe number:  220
# Measuring perplexity on test recipe number:  221
# Measuring perplexity on test recipe number:  222
# Measuring perplexity on test recipe number:  223
# Measuring perplexity on test recipe number:  224
# Measuring perplexity on test recipe number:  225
# Measuring perplexity on test recipe number:  226
# Measuring perplexity on test recipe number:  227
# Measuring perplexity on test recipe number:  228
# Measuring perplexity on test recipe number:  229
# Measuring perplexity on test recipe number:  230
# Measuring perplexity on test recipe number:  231
# Measuring perplexity on test recipe number:  232
# Measuring perplexity on test recipe number:  233
# Measuring perplexity on test recipe number:  234
# Measuring perplexity on test recipe number:  235
# Measuring perplexity on test recipe number:  236
# Measuring perplexity on test recipe number:  237
# Measuring perplexity on test recipe number:  238
# Measuring perplexity on test recipe number:  239
# Measuring perplexity on test recipe number:  240
# Measuring perplexity on test recipe number:  241
# Measuring perplexity on test recipe number:  242
# Measuring perplexity on test recipe number:  243
# Measuring perplexity on test recipe number:  244
# Measuring perplexity on test recipe number:  245
# Measuring perplexity on test recipe number:  246
# Measuring perplexity on test recipe number:  247
# Measuring perplexity on test recipe number:  248
# Measuring perplexity on test recipe number:  249
# Measuring perplexity on test recipe number:  250
# Measuring perplexity on test recipe number:  251
# Measuring perplexity on test recipe number:  252
# Measuring perplexity on test recipe number:  253
# Measuring perplexity on test recipe number:  254
# Measuring perplexity on test recipe number:  255
# Measuring perplexity on test recipe number:  256
# Measuring perplexity on test recipe number:  257
# Measuring perplexity on test recipe number:  258
# Measuring perplexity on test recipe number:  259
# Measuring perplexity on test recipe number:  260
# Measuring perplexity on test recipe number:  261
# Measuring perplexity on test recipe number:  262
# Measuring perplexity on test recipe number:  263
# Measuring perplexity on test recipe number:  264
# Measuring perplexity on test recipe number:  265
# Measuring perplexity on test recipe number:  266
# Measuring perplexity on test recipe number:  267
# Measuring perplexity on test recipe number:  268
# Measuring perplexity on test recipe number:  269
# Measuring perplexity on test recipe number:  270
# Measuring perplexity on test recipe number:  271
# Measuring perplexity on test recipe number:  272
# Measuring perplexity on test recipe number:  273
# Measuring perplexity on test recipe number:  274
# Measuring perplexity on test recipe number:  275
# Measuring perplexity on test recipe number:  276
# Measuring perplexity on test recipe number:  277
# Measuring perplexity on test recipe number:  278
# Measuring perplexity on test recipe number:  279
# Measuring perplexity on test recipe number:  280
# Measuring perplexity on test recipe number:  281
# Measuring perplexity on test recipe number:  282
# Measuring perplexity on test recipe number:  283
# Measuring perplexity on test recipe number:  284
# Measuring perplexity on test recipe number:  285
# Measuring perplexity on test recipe number:  286
# Measuring perplexity on test recipe number:  287
# Measuring perplexity on test recipe number:  288
# Measuring perplexity on test recipe number:  289
# Measuring perplexity on test recipe number:  290
# Measuring perplexity on test recipe number:  291
# Measuring perplexity on test recipe number:  292
# Measuring perplexity on test recipe number:  293
# Measuring perplexity on test recipe number:  294
# Measuring perplexity on test recipe number:  295
# Measuring perplexity on test recipe number:  296
# Measuring perplexity on test recipe number:  297
# Measuring perplexity on test recipe number:  298
# Measuring perplexity on test recipe number:  299
# Measuring perplexity on test recipe number:  300
# Measuring perplexity on test recipe number:  301
# Measuring perplexity on test recipe number:  302
# Measuring perplexity on test recipe number:  303
# Measuring perplexity on test recipe number:  304
# Measuring perplexity on test recipe number:  305
# Measuring perplexity on test recipe number:  306
# Measuring perplexity on test recipe number:  307
# Measuring perplexity on test recipe number:  308
# Measuring perplexity on test recipe number:  309
# Measuring perplexity on test recipe number:  310
# Measuring perplexity on test recipe number:  311
# Measuring perplexity on test recipe number:  312
# Measuring perplexity on test recipe number:  313
# Measuring perplexity on test recipe number:  314
# Measuring perplexity on test recipe number:  315
# Measuring perplexity on test recipe number:  316
# Measuring perplexity on test recipe number:  317
# Measuring perplexity on test recipe number:  318
# Measuring perplexity on test recipe number:  319
# Measuring perplexity on test recipe number:  320
# Measuring perplexity on test recipe number:  321
# Measuring perplexity on test recipe number:  322
# Measuring perplexity on test recipe number:  323
# Measuring perplexity on test recipe number:  324
# Measuring perplexity on test recipe number:  325
# Measuring perplexity on test recipe number:  326
# Measuring perplexity on test recipe number:  327
# Measuring perplexity on test recipe number:  328
# Measuring perplexity on test recipe number:  329
# Measuring perplexity on test recipe number:  330
# Measuring perplexity on test recipe number:  331
# Measuring perplexity on test recipe number:  332
# Measuring perplexity on test recipe number:  333
# Measuring perplexity on test recipe number:  334
# Measuring perplexity on test recipe number:  335
# Measuring perplexity on test recipe number:  336
# Measuring perplexity on test recipe number:  337
# Measuring perplexity on test recipe number:  338
# Measuring perplexity on test recipe number:  339
# Measuring perplexity on test recipe number:  340
# Measuring perplexity on test recipe number:  341
# Measuring perplexity on test recipe number:  342
# Measuring perplexity on test recipe number:  343
# Measuring perplexity on test recipe number:  344
# Measuring perplexity on test recipe number:  345
# Measuring perplexity on test recipe number:  346
# Measuring perplexity on test recipe number:  347
# Measuring perplexity on test recipe number:  348
# Measuring perplexity on test recipe number:  349
# Measuring perplexity on test recipe number:  350
# Measuring perplexity on test recipe number:  351
# Measuring perplexity on test recipe number:  352
# Measuring perplexity on test recipe number:  353
# Measuring perplexity on test recipe number:  354
# Measuring perplexity on test recipe number:  355
# Measuring perplexity on test recipe number:  356
# Measuring perplexity on test recipe number:  357
# Measuring perplexity on test recipe number:  358
# Measuring perplexity on test recipe number:  359
# Measuring perplexity on test recipe number:  360
# Measuring perplexity on test recipe number:  361
# Measuring perplexity on test recipe number:  362
# Measuring perplexity on test recipe number:  363
# Measuring perplexity on test recipe number:  364
# Measuring perplexity on test recipe number:  365
# Measuring perplexity on test recipe number:  366
# Measuring perplexity on test recipe number:  367
# Measuring perplexity on test recipe number:  368
# Measuring perplexity on test recipe number:  369
# Measuring perplexity on test recipe number:  370
# Measuring perplexity on test recipe number:  371
# Measuring perplexity on test recipe number:  372
# Measuring perplexity on test recipe number:  373
# Measuring perplexity on test recipe number:  374
# Measuring perplexity on test recipe number:  375
# Measuring perplexity on test recipe number:  376
# Measuring perplexity on test recipe number:  377
# Measuring perplexity on test recipe number:  378
# Measuring perplexity on test recipe number:  379
# Measuring perplexity on test recipe number:  380
# Measuring perplexity on test recipe number:  381
# Measuring perplexity on test recipe number:  382
# Measuring perplexity on test recipe number:  383
# Measuring perplexity on test recipe number:  384
# Measuring perplexity on test recipe number:  385
# Measuring perplexity on test recipe number:  386
# Measuring perplexity on test recipe number:  387
# Measuring perplexity on test recipe number:  388
# Measuring perplexity on test recipe number:  389
# Measuring perplexity on test recipe number:  390
# Measuring perplexity on test recipe number:  391
# Measuring perplexity on test recipe number:  392
# Measuring perplexity on test recipe number:  393
# Measuring perplexity on test recipe number:  394
# Measuring perplexity on test recipe number:  395
# Measuring perplexity on test recipe number:  396
# Measuring perplexity on test recipe number:  397
# Measuring perplexity on test recipe number:  398
# Measuring perplexity on test recipe number:  399
# Measuring perplexity on test recipe number:  400
# Measuring perplexity on test recipe number:  401
# Measuring perplexity on test recipe number:  402
# Measuring perplexity on test recipe number:  403
# Measuring perplexity on test recipe number:  404
# Measuring perplexity on test recipe number:  405
# Measuring perplexity on test recipe number:  406
# Measuring perplexity on test recipe number:  407
# Measuring perplexity on test recipe number:  408
# Measuring perplexity on test recipe number:  409
# Measuring perplexity on test recipe number:  410
# Measuring perplexity on test recipe number:  411
# Measuring perplexity on test recipe number:  412
# Measuring perplexity on test recipe number:  413
# Measuring perplexity on test recipe number:  414
# Measuring perplexity on test recipe number:  415
# Measuring perplexity on test recipe number:  416
# Measuring perplexity on test recipe number:  417
# Measuring perplexity on test recipe number:  418
# Measuring perplexity on test recipe number:  419
# Measuring perplexity on test recipe number:  420
# Measuring perplexity on test recipe number:  421
# Measuring perplexity on test recipe number:  422
# Measuring perplexity on test recipe number:  423
# Measuring perplexity on test recipe number:  424
# Measuring perplexity on test recipe number:  425
# Measuring perplexity on test recipe number:  426
# Measuring perplexity on test recipe number:  427
# Measuring perplexity on test recipe number:  428
# Measuring perplexity on test recipe number:  429
# Measuring perplexity on test recipe number:  430
# Measuring perplexity on test recipe number:  431
# Measuring perplexity on test recipe number:  432
# Measuring perplexity on test recipe number:  433
# Measuring perplexity on test recipe number:  434
# Measuring perplexity on test recipe number:  435
# Measuring perplexity on test recipe number:  436
# Measuring perplexity on test recipe number:  437
# Measuring perplexity on test recipe number:  438
# Measuring perplexity on test recipe number:  439
# Measuring perplexity on test recipe number:  440
# Measuring perplexity on test recipe number:  441
# Measuring perplexity on test recipe number:  442
# Measuring perplexity on test recipe number:  443
# Measuring perplexity on test recipe number:  444
# Measuring perplexity on test recipe number:  445
# Measuring perplexity on test recipe number:  446
# Measuring perplexity on test recipe number:  447
# Measuring perplexity on test recipe number:  448
# Measuring perplexity on test recipe number:  449
# Measuring perplexity on test recipe number:  450
# Measuring perplexity on test recipe number:  451
# Measuring perplexity on test recipe number:  452
# Measuring perplexity on test recipe number:  453
# Measuring perplexity on test recipe number:  454
# Measuring perplexity on test recipe number:  455
# Measuring perplexity on test recipe number:  456
# Measuring perplexity on test recipe number:  457
# Measuring perplexity on test recipe number:  458
# Measuring perplexity on test recipe number:  459
# Measuring perplexity on test recipe number:  460
# Measuring perplexity on test recipe number:  461
# Measuring perplexity on test recipe number:  462
# Measuring perplexity on test recipe number:  463
# Measuring perplexity on test recipe number:  464
# Measuring perplexity on test recipe number:  465
# Measuring perplexity on test recipe number:  466
# Measuring perplexity on test recipe number:  467
# Measuring perplexity on test recipe number:  468
# Measuring perplexity on test recipe number:  469
# Measuring perplexity on test recipe number:  470
# Measuring perplexity on test recipe number:  471
# Measuring perplexity on test recipe number:  472
# Measuring perplexity on test recipe number:  473
# Measuring perplexity on test recipe number:  474
# Measuring perplexity on test recipe number:  475
# Measuring perplexity on test recipe number:  476
# Measuring perplexity on test recipe number:  477
# Measuring perplexity on test recipe number:  478
# Measuring perplexity on test recipe number:  479
# Measuring perplexity on test recipe number:  480
# Measuring perplexity on test recipe number:  481
# Measuring perplexity on test recipe number:  482
# Measuring perplexity on test recipe number:  483
# Measuring perplexity on test recipe number:  484
# Measuring perplexity on test recipe number:  485
# Measuring perplexity on test recipe number:  486
# Measuring perplexity on test recipe number:  487
# Measuring perplexity on test recipe number:  488
# Measuring perplexity on test recipe number:  489
# Measuring perplexity on test recipe number:  490
# Measuring perplexity on test recipe number:  491
# Measuring perplexity on test recipe number:  492
# Measuring perplexity on test recipe number:  493
# Measuring perplexity on test recipe number:  494
# Measuring perplexity on test recipe number:  495
# Measuring perplexity on test recipe number:  496
# Measuring perplexity on test recipe number:  497
# Measuring perplexity on test recipe number:  498
# Measuring perplexity on test recipe number:  499
# 33.01349159167048
